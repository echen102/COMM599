# %%
import json
import nltk
# conda install -c conda-forge nltk
import spacy 
# conda install -c conda-forge spacy
from datetime import datetime
import tweepy
import re
import string
import unicodedata
from gensim import corpora
# conda install -c conda-forge gensim
from nltk.tokenize.toktok import ToktokTokenizer
### Sentiment analysis
from textblob import TextBlob
# conda install -c conda-forge textblob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# conda install -c conda-forge vaderSentiment

# %%
api_info = json.loads(open('../.secrets/twitter_api.json').read())

# %%
client = tweepy.Client(
    consumer_key       = api_info["api_key"],
    consumer_secret    = api_info["api_key_secret"],
    bearer_token       = api_info["bearer_token"],
    access_token       = api_info["access_token"],
    access_token_secret= api_info["access_token_secret"],
    wait_on_rate_limit = True
)

# %% [markdown]
# ### Query recent tweets

# %%
fields = "created_at,lang,author_id,text,referenced_tweets" 
expansions = "attachments.media_keys,referenced_tweets.id,author_id"

# %%
ukraine_tweets = client.search_recent_tweets(
    query="ukraine",
    max_results=100,
    tweet_fields=fields,
    expansions=expansions
)

# %%
def process_tweets(search_response):
    results  = search_response.data
    inc_tweets = search_response.includes['tweets']
    inc_tweets_data = [tweet.data for tweet in inc_tweets]
    tweets = []
    tweet_data = {}
    for tweet in results:
        tweet_data = tweet.data
        tweet_data["is_rt"]   = False
        tweet_data["rt_id"]   = None
        tweet_data["rt_text"] = None
        ref_tw = tweet.get('referenced_tweets')
        if ref_tw:
            rt = [rt for rt in ref_tw if rt.get('type')=="retweeted"]
            if len(rt) > 0:
                rt = rt[0]
                tweet_data["is_rt"]   = True
                tweet_data["rt_id"]   = rt.data['id']  
                tweet_data["rt_text"] = [inc['text'] for inc in inc_tweets_data if inc['id']==rt.data['id']][0]
        tweets.append(tweet_data)
    return tweets

# %%
processed_tweets = process_tweets(ukraine_tweets)

# %%
len(processed_tweets)
# Out:
# 100

# %%
next_token = None
all_tweet_data = []
for i in range(10):
    if i % 1 == 0:
        print('getting page {} ...'.format(i))
    if next_token:
        ukraine_tweets = client.search_recent_tweets(
            query="ukraine",
            max_results=100,
            tweet_fields=fields,
            expansions=expansions,
            next_token = next_token
        )
        tweet_data_list = process_tweets(ukraine_tweets)
    else:
        ukraine_tweets = client.search_recent_tweets(
            query="ukraine",
            max_results=100,
            expansions=expansions,
            tweet_fields=fields,
        )
        tweet_data_list = process_tweets(ukraine_tweets)
    all_tweet_data += tweet_data_list
    next_token = ukraine_tweets[3]['next_token']
# Out:
# getting page 0 ...
# getting page 1 ...
# getting page 2 ...
# getting page 3 ...
# getting page 4 ...
# getting page 5 ...
# getting page 6 ...
# getting page 7 ...
# getting page 8 ...
# getting page 9 ...

# %%
with open("../datasets/ukraine_tweets.json", "w") as outfile:
    json.dump(all_tweet_data, outfile, indent=4)

# %%
len(all_tweet_data)
# Out:
# 1000

# %% [markdown]
# ### Clean Tweets

# %%
def clean_tweet(tweet): 
    processed_tweet = tweet
    processed_tweet["id"] = tweet['id']
    processed_tweet["user"] = tweet['author_id']
    created_at = datetime.strptime(tweet["created_at"],"%Y-%m-%dT%H:%M:%S.%fZ")
    processed_tweet["created_at"] = created_at
    processed_tweet["lang"] = tweet['lang']
    
    if tweet['lang'] != "en":
        processed_tweet["is_en"] = False
    else: 
        processed_tweet["is_en"] = True
            
    return processed_tweet

# %%
tweet_data_list = json.loads(open('../datasets/ukraine_tweets.json').read())
len(tweet_data_list)
# Out:
# 1000

# %%
# filter all of the raw tweets by turning them into clean_tweet objects
# the filtering is taken care of in the class function
filtered_data = []
for elem in tweet_data_list: 
    filtered_tweet = clean_tweet(elem)
    filtered_data.append(filtered_tweet)

# %%
len(filtered_data)
# Out:
# 1000

# %%
# Re-serialize dates and save raw data
clean_tweets_json = []
for fd in filtered_data:
    fd['created_at'] = datetime.strftime(fd['created_at'],"%Y-%m-%dT%H:%M:%S.%fZ")
    clean_tweets_json.append(fd)
with open("../datasets/ukraine_tweets_clean.json", "w") as outfile:
    json.dump(clean_tweets_json, outfile, indent=4)

# %% [markdown]
# ### Process data

# %%
filtered_data = json.loads(open('../datasets/ukraine_tweets_clean.json').read())

# %%
# create a list of all the tweet text 
# we filter out all tweets that are not English
tweet_text = []
for tweet in filtered_data:
    if tweet["is_en"]:
        if tweet.get("is_rt"): 
            tweet_text.append(tweet["rt_text"].replace("\n", " "))
        else:
            tweet_text.append(tweet["text"].replace("\n", " "))

# %%
# There are fewer than 1,000 since filtered for english tweets
len(tweet_text)
# Out:
# 827

# %% [markdown]
# ### Preprocessing Data

# %%
# remove HTML links, mentions, hashtags, and special characters

def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ' ')    
    return text

def strip_mentions(text):
    entity_prefixes = ['@']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

def strip_hashtags(text):
    entity_prefixes = ['#']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)
        
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
stripped_tweet_text = []
for elem in tweet_text:
    elem = strip_links(elem)
    elem = strip_mentions(elem)
    elem = strip_hashtags(elem)
    elem = elem.replace('RT', '')
    elem = remove_special_characters(elem)
    stripped_tweet_text.append(elem)

# %%
tweet_text[119]

# %%
stripped_tweet_text[119]

# %%
tweet_text[171]

# %%
stripped_tweet_text[171]

# %% [markdown]
# ### Sentiment Analysis

# %%
for i,elem in enumerate(stripped_tweet_text):
    elem_textblob = TextBlob(elem)
    sent = elem_textblob.sentiment
    print (elem)
    print(sent)
    print ("----")
# Out:
# Ukrainian player of Manchester City football club Oleksandr Zinchenko enters the field with a Ukrainian flag Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Bunker broadcast with  CliveMyrieBBC and big thanks to  DeeMcIlveen Robbie Wright  OpsBbc James White amp Ian Jonas  katepeters Kyiv Ukraine
# Sentiment(polarity=0.06666666666666667, subjectivity=0.10000000000000002)
# ----
# Ukraine Women amp children are especially vulnerable to the devastating consequences of the ongoing conflict is scaling up efforts to protect children in the country and warning that many young people are profoundly traumatized by the violence
# Sentiment(polarity=-0.2633333333333333, subjectivity=0.78)
# ----
# This is a dangerous time in history since the Cuban Missile Crisis Our president won t withhold aid to Ukraine in exchange for dirt on a political opponent Our leaders must be sane competent people VoteBlueNotQ wtpBLUE
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.5555555555555555)
# ----
# Front line reporters in Ukraine are risking their lives to tell us what they can learn As for the rest I m surprised there hasn t been more reporting on Gen Gerasimov the military mover behind Putin He specializes in multidimensional war including kinetic finance and cyber
# Sentiment(polarity=0.024999999999999994, subjectivity=0.55)
# ----
# Russia did not invade under Trump Trump armed Ukraine Presidential debate final and most important didnt cover foreign policy as the world was approaching total peace Trump was the peacemaker America was strong These are only the facts
# Sentiment(polarity=0.15104166666666666, subjectivity=0.6385416666666667)
# ----
# Ive never been so proud of my country and the president Ive voted for ukraine
# Sentiment(polarity=0.8, subjectivity=1.0)
# ----
# Three NATO Cuntries Bulgaria Poland Slovakia to Transfer 70 Combat Airplanes to Ukraine  TASS
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Tonight congressional Republicans have a choice support and show unity against Russias war on Ukraine or take cheap shots from the gallery and weaken America I hope they look to the unity among all parties in Ukraine as a model for rallying against evil SOTU
# Sentiment(polarity=-0.3, subjectivity=0.85)
# ----
# Howard needs to parachute into Ukraine with an AR 15 and fight the enemy himself
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Quick thread I want you all to meet Vladimir Bondarenko Hes a blogger from Kiev who really hates the Ukrainian government He also doesnt exist according to Facebook Hes an invention of a Russian troll farm targeting Ukraine His face was made by AI
# Sentiment(polarity=0.17777777777777778, subjectivity=0.2333333333333333)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Update Canada is stepping up to provide more humanitarian support in Ukraine and neighbouring countries This support will help experienced partners provide emergency health services shelter sanitation food and water and more More details here
# Sentiment(polarity=0.575, subjectivity=0.6)
# ----
# Solidarity with the people of Ukraine  IStandWithUkriane   Trafalgar Square London
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# At 12000 around 60 of Indians in Ukraine have left the country Of the 40 20 are with western border of Ukraine while 20 in conflict zone
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Japan US EU to aid refugees after Russia s invasion of Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I wish the world would hear this Ukraines chief rabbi Could I have thought that I would be under bombardment of the country where I was born where I have so many friends Who are silent Ppl from all over the world called me Except from Russia
# Sentiment(polarity=0.25, subjectivity=0.3)
# ----
# There you have it Like all wars started by amp funded by the Rothschilds Putin is removing the deep state cabal WEF UN ClintonFoundation 5Eyes Biden Mi5 MOSSAD CIA black hat operators OUT of Ukraine RussianArmy are NOT attacking civilians RussianUkrainianWar
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.4166666666666667)
# ----
# A follower said when she heard the piano she burst out in tears I was touched also This is a man possibly about to die playing his heart amp the heart of Ukraine to the world Please Retweet Russia Putin Russianinvasion UkrainianArmy PutinWarCriminal
# Sentiment(polarity=0.0, subjectivity=1.0)
# ----
# Wow The Russian Federation has been served by the International Court of Justice The Hague is Calling Out Genocide On Behalf of Ukraine
# Sentiment(polarity=0.03333333333333333, subjectivity=0.3333333333333333)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Did soldiers punch holes in ALL of the trucks armor gas tanks
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
#  Natasha Perakov 29 years old the first Ukrainian fighter pilot died in combat during the Russian invasion of Ukraine Russia Ucrania Ukraine Kyiv Kiev SlavaUkraini
# Sentiment(polarity=0.11666666666666665, subjectivity=0.17777777777777778)
# ----
# Answer to Is there anything that makes you smile about this horrible war between Russia and Ukraine by Jacob Dave Harrelson
# Sentiment(polarity=-0.35, subjectivity=0.55)
# ----
# Ukraine came to help us in 91
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Ukraines Propaganda Offensive Led By Ad Tech Entrepreneurs Appears To Be Winning
# Sentiment(polarity=0.2, subjectivity=0.425)
# ----
# Please do this Go to Google maps go to Moscow or St Petersbourgh pick a restaurant and give a review telling the people in Russia what s happening in Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# News Analysis After miscalculating Ukraines resolve to fight Russian forces are turning to an old pattern of firing on cities and mounting sieges
# Sentiment(polarity=0.05, subjectivity=0.1)
# ----
# Global charities operating in the UK and Ukraine are appealing for funds to offer aid in the humanitarian crisis bitcoin bc1q8skvh9xsjgntvs0mv3g3pxd8k8xl7spdm82wcf
# Sentiment(polarity=0.25, subjectivity=0.25)
# ----
# OH MY GOD Q Whats going on in Ukraine  Kamala Ukraine is a country in Europe It exists next to another country called Russia Russia is a bigger country Russia decided to invade a smaller country called Ukraine so basically thats wrong
# Sentiment(polarity=-0.125, subjectivity=0.475)
# ----
# Ukrainians fleeing war are receiving a hearty welcome in Poland Hungary and other neighboring counties The different treatment is stark compared to that of Middle Eastern and African migrants and refugees particularly Syrians who came in 2015
# Sentiment(polarity=0.09166666666666667, subjectivity=0.4011904761904762)
# ----
# BREAKING NEWS U S officials announce that the Russian offensive on Kyiv Ukraines capital is completely stalled  and many Russian battle units have surrendered without a fight   IF YOU THINK THAT THIS IS GREAT NEWS
# Sentiment(polarity=0.27999999999999997, subjectivity=0.32999999999999996)
# ----
# STOP RUSSIAN AGGRESSION AGAINST UKRAINE CLOSE THE SKY OVER UKRAINE EXCLUDE RUSSIA FROM THE SECURITY COUNCIL StopPutin StopRussiacn
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
#  For the past several months the have STOOD IN SOLIDARITY with VladimirPutin as he inched CLOSER to WAR declared Ukraine strategically irrelevant to the US
# Sentiment(polarity=-0.25, subjectivity=0.4166666666666667)
# ----
# At least 11 people were killed in rocket strikes in residential areas of Kharkiv as both sides readied for a major battle over Ukraine s second largest city
# Sentiment(polarity=-0.109375, subjectivity=0.225)
# ----
# Hello world How are your kids today Where do they sleep Where do they play Are Russian shells dropping on them Well in Ukraine this is life for the little ones And as I write this the Russian shells are still falling
# Sentiment(polarity=-0.0625, subjectivity=0.16666666666666666)
# ----
# Jakobowski Traczyk worry that China might conclude from the US decision not to send troops to Ukraine  which is neither a Nato member nor an ally  that it would not defend Taiwan it was an intellectually lazy comparison
# Sentiment(polarity=-0.25, subjectivity=1.0)
# ----
# Forbes More Russian Billionaires Speak Out Against Putin s War On Ukraine via
# Sentiment(polarity=0.25, subjectivity=0.25)
# ----
# Biden sent Kamala to help defend Ukraines borders but not our own Biden buys Russian crude oil while crushing American energy independence Bidens America Last policies are hurting the very people he is supposed to serve We wont forget this come Election Day
# Sentiment(polarity=0.07142857142857142, subjectivity=0.4666666666666667)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Jarosaw Perzyski the mayor of a Polish town drove 7 hours to the Ukrainian border where he has handed out stuffed toys to kids whose families are fleeing the Russian invasion From our children to the Ukrainian children  he said handing out gifts
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Sasha chose to stay in Ukraine to take care of her animal rescues Last night a Russian rocket hit her home Her son found her body this morning Another innocent life ended by war RIP Sasha of Ukraine Fkn heartbreaking
# Sentiment(polarity=0.16666666666666666, subjectivity=0.25555555555555554)
# ----
# Airstrikes on Kyiv hit a Holocaust memorial Ukrainian official says
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Ukraine conflict UK sanctions Belarus for role in Russian invasion
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Miss B Russia vs Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# The illegal and unprovoked invasion of Ukraine is continuing The map below is the latest Defence Intelligence update on the situation in Ukraine 01 March 2022 Find out more about the the UK Government s response  StandWithUkraine
# Sentiment(polarity=0.16666666666666666, subjectivity=0.6333333333333333)
# ----
# KSA and UAE two US security dependents have influence over energy markets that make their views on Russia and Ukraine more consequential than any US org to the left of the Democratic party But criticizing them online is less consequential yeah well there you go
# Sentiment(polarity=0.11111111111111112, subjectivity=0.18888888888888888)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Between Russia and Ukraine Priyanka Chaturvedi is fighting with Poland
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# There is a war in Ukraine my home country I am in Poland But my parents friends are still there fighting for our country and their lives All the proceeds will go to support the Ukrainian Army Link is below stopputin stopwar
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Be Prepared for Cyber Attack America  MSNBC  Newsweek  CNN  RuhleOnMSNBC Business big and Small are Cyber Target Most Fortune 500 Companies pay more money in CEO Bonus then they spend on Cyber Defense  DHSgov
# Sentiment(polarity=0.1875, subjectivity=0.375)
# ----
# All 4 MEPs voted against it As did only MEP When it comes to choosing between money and Ukraine money won Putin will be pleased
# Sentiment(polarity=0.25, subjectivity=1.0)
# ----
# Unarmed citizens trying to block the advance of Russian troops in the Nikolaev region Ukraine Russia RussianUkrainianWar RussiaInvadesUkraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING REPO Ukrainian Parliament Member Tells Fox News We Not only Fight For Ukraine  We Fight For this NEW WORLD ORDER
# Sentiment(polarity=0.06818181818181818, subjectivity=0.7272727272727273)
# ----
# OPEC signals it will to stick to plan despite Ukraine invasion
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.16666666666666666)
# ----
# Update Canada is stepping up to provide more humanitarian support in Ukraine and neighbouring countries This support will help experienced partners provide emergency health services shelter sanitation food and water and more More details here
# Sentiment(polarity=0.575, subjectivity=0.6)
# ----
# BREAKING An elite Chechen fighting unit that was sent into Ukraine to kill President Zelensky has been ELIMINATED It was sent by the leader of Russias Chechnya region who is a close ally of Putin
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Hello baby lovers Any chance of blue and yellow pampers Ukraine colours coming to the world Hell I ll purchase some British ones if you can sell me some Union Jacks
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
# ----
# We gotta stop looking to do things that aren t going to happen There won t be a no fly zone There won t be NATO troops in Ukraine We need to find what we can do that has maximum effect in the realm of the possible
# Sentiment(polarity=-0.2, subjectivity=0.95)
# ----
# Khamenei In my view Ukraine is a victim of the crises concocted by the United States There are two lessons to be learnt here States which depend on the support of the U S and Western powers need to know they cannot trust such countries
# Sentiment(polarity=-0.025000000000000005, subjectivity=0.18333333333333335)
# ----
# For those who are paying attention to Ukraine but know little about its recent history or people please see the documentary Winter On Fire
# Sentiment(polarity=-0.0625, subjectivity=0.25)
# ----
#  Trump froze military assistance to Ukraine they said nothing Withheld a White House meeting with Zelenskyy So we are not gonna be lectured by them   Rep Jim McGovern D MA goes off on House Minority Leader McCarthy blaming Russias invasion of Ukraine on Biden
# Sentiment(polarity=-0.05, subjectivity=0.05)
# ----
# contextualizes Russia s invasion of Ukraine and attempts to provide nuance Putin Zelenskyy Biden
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# EOS Data Analytics issues urgent plea for imagery of Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# on Russias human right abuses in Ukraine Violence has driven over half a million Ukrainians from the country in just a few days including children the elderly and people with disabilities who are making harrowing journeys through conflict zones
# Sentiment(polarity=-0.020238095238095243, subjectivity=0.22559523809523807)
# ----
# Janus Henderson on Russia Ukraine via EM lens India is experiencing a boom in business models across all digital verticals funded from domestic multinational and public private equity investors  this will not be Russias future ausbiz
# Sentiment(polarity=0.0, subjectivity=0.13333333333333336)
# ----
# Canada closes ports territorial waters to Russian ships The new ban will become part of the sanctions introduced by Canada over Russias all out attack on Ukraine
# Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# ----
# Sad news from Ukraine confirming the death of Ihir Usyk pictured here wearing his Rangers Jersey Ihir a Ukrainian citizen died defending his country And when all my life has ended amp death has made it s mark Will you scatter all my ashes On the slopes of Ibrox Park
# Sentiment(polarity=-0.5, subjectivity=1.0)
# ----
# Ukraine Grateful for William and Kate Support After Meghan and Harry Backlash England William amp Kate If You Wan Stay On Thing You Har Reedy Nation Whitt Plenty To Sy Many Change amp You Not Har Not So Clean You Har One Off The Country You Hon The Sleve
# Sentiment(polarity=0.22222222222222224, subjectivity=0.45)
# ----
# The United States is responsible for what happened in Ukraine the instigator is the U S Lebanon s Hezbollah leader Sayyed Hassan Nasrallah said on Tuesday He also criticized Western countries double standards in handling the Ukraine crisis
# Sentiment(polarity=0.06666666666666667, subjectivity=0.18333333333333335)
# ----
# This is from anonymous Go to Google maps Type in Russia Type in a city in Russia Click on restaurants Leave a five star review and let them know what is really going on in the Ukraine Advise to get news from outside the country
# Sentiment(polarity=0.1, subjectivity=0.125)
# ----
# Practically Ukraine lost entire coast of Azov Sea
# Sentiment(polarity=0.0, subjectivity=0.625)
# ----
# I don t believe anything out of Ukraine and Russia Why George Soros and The World Economic Forum are involved
# Sentiment(polarity=0.2, subjectivity=0.2)
# ----
# Wash Post s Hugh Hewitt and Fox News Mike Pompeo lie about Trump s extortion of Ukraine Via Media Matters
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# You might not like the messenger but the message is important Putin please stop this war Evening Standard
# Sentiment(polarity=0.2, subjectivity=0.5)
# ----
# 01 03 2022 StandWithUkraine Ukraine kyiv Not Verified
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Excellent Now we just need the UK US to buy it from the receivers and then fill the damned thing in UkraineUnderAttack Ukraine SlaviaUkraini Russia PiersMorgan
# Sentiment(polarity=1.0, subjectivity=1.0)
# ----
# Rather than expressing grief BJP leader amp Union Minister NarayanRane mocking death on Indian student s death BJP should condemn d behaviour of Mr Rane amp should apologize Ukraine indianstudents IndiansInUkraine Shivsena BJP
# Sentiment(polarity=-0.8, subjectivity=0.2)
# ----
# Stop killing our children Close the sky over Ukraine Exclude russia from the Security Council EN StopPutin StopRussia
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Consider how all the War Departments and Ministries over the world were renamed into Defence in late 1940s Everyone s defending nobody s attacking Why does the fighting happen then Well because of criminals bandits terrorists jihadees or as now in Ukraine Nazis
# Sentiment(polarity=-0.3, subjectivity=0.6)
# ----
# With Corrupt Politicians and a Corrupt Media How Do We Know What Is Best for the US Concerning Ukraine by
# Sentiment(polarity=0.0, subjectivity=0.7666666666666666)
# ----
# BREAKING McDonalds and KFC will distribute food to Ukranian soldiers and Ukrainians in need  to thank and for STANDING up against Putin s ILLEGAL invasion of Ukraine
# Sentiment(polarity=-0.5, subjectivity=0.5)
# ----
# Turkish footballer Aykut Demir caused a stir after refusing to wear No To War T shirt in solidarity with Ukraine Thousands of people die every day in the Middle East I feel said too I share the pain of innocent people  Turkey UkraineRussiaWar UkraineRussia
# Sentiment(polarity=0.25, subjectivity=0.35)
# ----
# I See A lot Of People In This Country Are Rightfully Rallying Behind Ukraine In Its Fights Against Russia Imagine If This Country Rallied Behind Racism Sexism amp Voters SuppressionThe Same Way
# Sentiment(polarity=-0.26666666666666666, subjectivity=0.5083333333333333)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Finnish demonstrators singing today at Russian Embassy in Helsinki a patriotic Finlandia Hymn that was written during a russification period of Finland by Jean Sibelius at the beginning of the 20th century Finland is changed in lyrics to Ukraine Leaded by the  YLChoir
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Russia s censor Roskomnadzor threatens to block Wikipedia for an article on The Russian invasion of Ukraine 2022
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Very heavy Russian MLRS shelling with cluster munitions on Ukraine s Kharkiv City tonight Whenever the Russians and Assad failed to capture a city in Syria they used cluster munitions to punish the besieged people and force them to surrender
# Sentiment(polarity=-0.25333333333333335, subjectivity=0.31666666666666665)
# ----
# 15 things the mainstream media will not show you about whats happening in Ukraine right now
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# ----
# Belarusians are preventing Russian troops and vehicles from moving inside Belarus Bypol reported Belarusians started to disrupt the operation of railways that carry Russian tanks and cars to the Belarus Ukraine The people of Belarus stand with our neighbors
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Nobody want to unfollow you I born in Snina Slovakia the nearest border is Uba like 30km from Ukraine border I understand your feelings
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Stop killing our children Close the sky over Ukraine Exclude russia from the Security Council EN StopPutin StopRussia
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# NEW Russia has deployed launching systems capable of sending deadly thermobaric rockets at Ukrainian targets a senior U S defense official said today Russia is likely to employ the weapons to terrorize the Ukrainian army and resistance experts said
# Sentiment(polarity=0.03409090909090909, subjectivity=0.5636363636363636)
# ----
# This is Amazing 80k volunteer soldiers from around the world to join  Forces Poland Ukraine will be forever indebted for your tremendous help during these hard times
# Sentiment(polarity=0.21388888888888888, subjectivity=0.8138888888888888)
# ----
# I m more likely to believe NATO CIA AZOV or Ukraine will blow it up themselves In order to blame Russia Than to think Putin would do that But Who knows
# Sentiment(polarity=0.25, subjectivity=0.75)
# ----
# Where s Kyle Rittenhouse and his gun Does he want to do something about the Ukraine v Russia war Can he get his mom to bring him over county lines again to go defend against an unruly and dangerous mob Or does his ideals align too much with the person doing the damage idk
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.55)
# ----
# RUSSIAN INVASION OF UKRAINE LATEST  At least 10 people killed 20 wounded in Kharkiv attack interior ministry adviser says  Zelenskyy If we defend Kyiv we defend the country  Ukrainian ambassador to the U S says Russia used vacuum bomb
# Sentiment(polarity=-0.0016666666666666666, subjectivity=0.26)
# ----
# Hey Lincolnshire Did you vote to be represented like this Is this your values being portrayed to the World including Ukraine I am guessing not I think you d better have a word with your MP Oh A Sir no less too PutinsToryPuppet
# Sentiment(polarity=0.2916666666666667, subjectivity=0.2833333333333333)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Burn motherfucker burn Russian Pantsir S1 missile system destroyed in Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Lithuanians have donated 10 mil EUR via Blue Yellow At the moment these items are bought and being shipped to Ukraine Military outfits for 130k Optical lenses for 80k Helmets for 810k Bulletproof vests for 630k Medical equipment for 190k Satellite phones for 200k
# Sentiment(polarity=-0.025, subjectivity=0.05)
# ----
# Raab the son of a man given refuge in this country from the Nazis is on the radio right now repeating the line that most people want to stay in Ukraine No one is suggesting we force them here Just offer refuge to those who are fleeing why is that so hard
# Sentiment(polarity=0.16468253968253968, subjectivity=0.5257936507936507)
# ----
# Schumer on Ukraine supplemental spending bill We should be bipartisan on this issue Nothing make Putin happier than for us to be divided
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Oh but they re trying to de Nazify Ukraine smh
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING Soldiers from Belarus have now also invaded Ukraine ALL sanctions against Russia should now be extended 100 to cover Russia AND Belarus
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Reporting with on Ukrainian Canadians and those with no family ties heading to Ukraine to fight Russian aggression Many are flying out tonight UkraineRussiaWar
# Sentiment(polarity=0.25, subjectivity=0.25)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# If the entire Russian army joined Ukraine  with that insane round rage monster hiding in his city under ground surrounded by his little servants and yes men every one too scared or equally insane to step up He will just press his shiny red button and we are all screwed
# Sentiment(polarity=-0.3410714285714286, subjectivity=0.5035714285714286)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I m leaving the safety of my home in Harrow taking aid to Ukraine  and bringing back desperate refugees I m very apprehensive but their need is bigger than mine Wish us luck we ll post on FB and twitter It s going to be grim but I can no longer sit in Harrow and watch X
# Sentiment(polarity=-0.27999999999999997, subjectivity=0.5599999999999999)
# ----
# For those who are paying attention to Ukraine but know little about its recent history or people please see the documentary Winter On Fire
# Sentiment(polarity=-0.0625, subjectivity=0.25)
# ----
# Well be there ukraine Find your local protest here StopTheWar ClimateJustice StandWithUkraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Naveens fathers statement should spark a debate about the state of medical education in India He laments about caste based quota and expensive private medical education worth crores  all the reasons why he chose to send his son to Ukraine This should not be ignored
# Sentiment(polarity=-0.04, subjectivity=0.23500000000000001)
# ----
# Truly inspiring how crises unite us Indians as one large family Successful amp bright young Indian professionals living in Hungary have taken off from work to selflessly volunteer to help amp assist the students who are coming from Ukraine Kudos for their efforts amp kindness
# Sentiment(polarity=0.45285714285714296, subjectivity=0.7157142857142856)
# ----
# The UK will take up to 200 000 refugees from Ukraine who have sponsors or family in the UK The government restricts asylum for Syrian Iraqi and other MENA refugees  most wait 6 months for processing  and backed pushbacks of refugees at sea after 28 000 crossed last year
# Sentiment(polarity=0.125, subjectivity=0.3138888888888889)
# ----
# The Europeans are willing to stand up to Russia because they know that Washington has their backs Without staunch U S support which they would never get from Trump the unprecedented Western resolve would melt as quickly as the last snow of spring
# Sentiment(polarity=0.23666666666666666, subjectivity=0.44333333333333336)
# ----
# Thousands of Russians have been arrested for opposing Vladimir Putins war on Ukraine A socialist detained by police during a protest in Saint Petersburg writes about her arrest and the antiwar movements defiance in the face of state repression
# Sentiment(polarity=-0.05, subjectivity=0.0)
# ----
# Black students in Ukraine are trapped in basement bunkers struggling to get food money or even an escape route out of the country and you folks are helping Terrell Starr go viral lying about Ukraines neo Nazi problem while they sit and wait to be rescued
# Sentiment(polarity=-0.18333333333333335, subjectivity=0.21666666666666667)
# ----
# Biden wearing a mask in support of Ukraine aint enough Ukraine needs proper help time to be courageous like Zelenskyy dont be a USCoward
# Sentiment(polarity=0.0, subjectivity=0.3)
# ----
# To be clear there appears to be significant public disapproval within Belarus to invading Ukraine Protests social media activity and even sabotage to stop Russian military transports from moving through It may be the beginning of a democratic awakening in Belarus
# Sentiment(polarity=0.06805555555555558, subjectivity=0.24861111111111112)
# ----
# Pat Robertson Putin is being compelled by God to invade Ukraine and fulfill biblical prophecy Is he the modern day Assyrian
# Sentiment(polarity=0.2, subjectivity=0.3)
# ----
# Russian forces escalate attacks on Ukraine s civilian areas from
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# The number of Russian soldiers killed in Ukraine since February 24 now exceeds 5 000 see Russian source below 1 000 a day This is more than in 8 years of war in Syria Syrian mothers can feel revenged Syrian and Turkish friends please share
# Sentiment(polarity=0.075, subjectivity=0.125)
# ----
# Be aware of fake war footage from the Ukraine doing the rounds
# Sentiment(polarity=-0.125, subjectivity=0.625)
# ----
# weeman Androwski dont care them You cant tell that is what a stupid idea They eyes full with blood right now Humanitarian support is only all we can do Ukraines president should stop expecting more Its not innocent peoples of other countries fight
# Sentiment(polarity=-0.00561224489795918, subjectivity=0.6658163265306122)
# ----
# It only took 4 days for almost complete global condemnation of Putin for invading Ukraine but we re on Day 715 of 15 Days to Slow the Spread and Xi just finished hosting the Olympics in Beijing with near total backing of global corporations and the media
# Sentiment(polarity=-0.01428571428571429, subjectivity=0.4214285714285714)
# ----
# I spent most of the day checking on points of defense in Kyiv My resistance team is helping out organize the supplies and patrol the city The fun part is people did not expect MPs to stay in town they thought we fled No we did not We are here to fight together Ukraine
# Sentiment(polarity=0.2333333333333333, subjectivity=0.26666666666666666)
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.16666666666666666)
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# See our Chief Investment Officers weekly take on the markets
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# As per CNN a Russian air strike destroyed a Holocaust memorial near Kyiv Putin thats a funny way of denazifying Ukraine you son of bitch you
# Sentiment(polarity=0.11666666666666665, subjectivity=0.4666666666666666)
# ----
# Fight back and spread awareness by peeing on Putin literally PEETIN NFT collection for Ukraine fundraising You can find more details here Get them on Opensea Discord
# Sentiment(polarity=0.25, subjectivity=0.25)
# ----
# 31 10 20 Hunter Bidens Ukraine contact allegedly a fixer for shady oligarchs Down the rabbithole Nederland HunterBiden Corruption
# Sentiment(polarity=-0.1685185185185185, subjectivity=0.33796296296296297)
# ----
# Amnesty Internationals Crisis Evidence Lab analyzed digital evidence  including photos videos and satellite imagery of indiscriminate attacks in Ukraine They have verified violations of international law which could amount to war crimes
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# So should we send the freedom fighters from the trucker convoys to Ukraine so they can see what fighting for freedom actually looks like
# Sentiment(polarity=0.0, subjectivity=0.1)
# ----
# I spent most of the day checking on points of defense in Kyiv My resistance team is helping out organize the supplies and patrol the city The fun part is people did not expect MPs to stay in town they thought we fled No we did not We are here to fight together Ukraine
# Sentiment(polarity=0.2333333333333333, subjectivity=0.26666666666666666)
# ----
# A lot of people are quoting Marco Rubio on Ukraine They should ask him why he voted to give Donald Trump a pass for illegally withholding military aid from Ukraine
# Sentiment(polarity=-0.3, subjectivity=0.3)
# ----
# Media exploitation of Russia Ukraine is almost as apalling as their coverage of COVID in terms of using unverified material and creating sensationalism and bias No surprise at all
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I just spoke with President Zelenskyy to discuss our continued support for Ukraine  including security assistance and humanitarian aid  as it defends itself against Russian aggression We will hold Russia accountable and our sanctions are already having a devastating impact
# Sentiment(polarity=-0.5, subjectivity=0.5)
# ----
# BREAKING Ukraine s Secretary of the Security Council announces that the elite squad of killers sent by Chechen dictator Ramzan Kadyrov to kill Ukrainian President Zelenskyy on behalf of Putin have been eliminated  IF YOU THINK THIS IS GREAT NEWS
# Sentiment(polarity=0.8, subjectivity=0.75)
# ----
# I m probably alone in being confused about Belarus stance on Ukraine Reporting is all over the place On balance it seems like Belarus is rope a doping Putin
# Sentiment(polarity=-0.4, subjectivity=0.7)
# ----
# Why is Apple mum on Ukraine Hey  Apple  tim cook
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Located the tank training facility reportedly attacked by Russia in Kharkiv Ukraine 49 972141 36 166573
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# People in our community want to express solidarity with Ukraine and show that we are against the war This is the least we can do Tune in 29 02 22 at 18 00 UTC 2 for a 24 hour Skullgirls marathon stream Artwork by NoWar
# Sentiment(polarity=-0.3, subjectivity=0.4)
# ----
# Even the Super Heroes tonight pray for peace between Russia and Ukraine for peace in Europe FatTuesdayofPrayer
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.16666666666666666)
# ----
# Poll Amrach Research Q Would you welcome Ukraine as a member of the EU Yes 84 No 5 Unsure 11 February 2022 S 1 000
# Sentiment(polarity=0.8, subjectivity=0.9)
# ----
# Two leaders two worlds Freedom will prevail
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Why is no one covering this Pushed back because were Black Africans stranded at Ukraine Poland border via
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667)
# ----
# That viral video of Ukraines President powerfully shutting down a homophobic heckler  now with more context by A rare public exhibit of passion in defending progressive values by a European leader these days
# Sentiment(polarity=0.1574074074074074, subjectivity=0.4592592592592593)
# ----
# Here is every single member of the European parliament who voted against supporting Ukraine A mix of far right and far left populists Save this list vote them out in 2024
# Sentiment(polarity=0.09489795918367347, subjectivity=0.42857142857142855)
# ----
# Current scenes from Ukraine devastating
# Sentiment(polarity=-0.5, subjectivity=0.7)
# ----
# Thread The most racist Ukraine coverage on TV News 1 The BBC Its very emotional for me because I see European people with blue eyes and blonde hair being killed Ukraines Deputy Chief Prosecutor David Sakvarelidze
# Sentiment(polarity=0.049999999999999996, subjectivity=0.24083333333333337)
# ----
# 5 vile things Trump did to Zelensky amp Ukraine that you forgot about The tfg s track record on Ukraine raises questions about what would happen if he were POTUS again questions that to put it mildly are deeply unsettling indeed StandWithUkraine
# Sentiment(polarity=-0.08333333333333334, subjectivity=0.6)
# ----
# Every voice matters We see you and feel your support Urge your governments to provide Ukraine with more defensive weapons ammunition and economic support Cut all political and business ties with Russia Tell us what country you are supporting us from  StandWithUkraine
# Sentiment(polarity=0.2375, subjectivity=0.26249999999999996)
# ----
# The U S has dropped at least 337 000 bombs in the past 20 years and has bombed Syria for 5 years Yemen for 7 years Somalia for 15 years Iraq for 16 years Pakistan for 18 years Afghanistan for 21 years But now you care about Ukraine Exactly when the media tells you to
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.3)
# ----
# NoWar We stand for Ukraine SlavaUkraini Practical tips in the thread how you can show support with your website NoCode
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Andrew who has family stuck in Moldova having fled Ukraine says he was told by the Home Office to call back next Monday He says they are charging a fee for the application process Surely surely not
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.2962962962962963)
# ----
# Putin has gone berserk and the civilized world should stop all dealings with Russians until this Tyrant is out of power Russian people need to rise and stop this brutality on Russians who have made Ukraine their peaceful home
# Sentiment(polarity=0.21666666666666667, subjectivity=0.4666666666666666)
# ----
# If you support the announcement that Ukraine will offer money and asylum to any Russian soldier who voluntarily surrenders and abandons the war hit the like button and follow so you don t miss important Ukraine news or a chance to RESIST Putin s ILLEGAL invasion
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.5)
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING An elite Chechen fighting unit that was sent into Ukraine to kill President Zelensky has been ELIMINATED It was sent by the leader of Russias Chechnya region who is a close ally of Putin
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# If Tucker wants to know why ppl say he roots for Russia it s because in Dec 2019 he said We should probably take the side of Russia And in November 2021 he said Why would we take Ukraine s side Why aren t we on Russia s side
# Sentiment(polarity=0.2, subjectivity=0.1)
# ----
# Lets make science not war Russian scientists amp science journalists have published an open letter condemning the war with Ukraine calling it unfair and senseless currently over 4 000 signatories Russian English
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.31666666666666665)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Did Ukraine turn Anakin to the dark side No End of story
# Sentiment(polarity=-0.15, subjectivity=0.4)
# ----
# BREAKING President Zelensky asks the United Nations to STRIP Russia s vote at the UN Security Council as punishment for invading Ukraine Should they
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# ua director berates Boris Johnson over the UKs failure to impose tougher sanctions against Russians resident in London or push for a no fly zone over Ukraine during press conference in Poland
# Sentiment(polarity=-0.3583333333333334, subjectivity=0.6)
# ----
#  Ukraine s minister of culture says Russia s army plans to destroy a 1000 years old Saint Sophia Cathedral They seek to destroy the entire Ukrainian history trying to steal it  Stalin blew up the neighbouring cathedral which was slightly younger UkraineInvasion
# Sentiment(polarity=-0.06000000000000001, subjectivity=0.16499999999999998)
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.16666666666666666)
# ----
# Videos show the destruction of Freedom Square in Kharkiv after an apparent rocket struck an administrative building earlier on Tuesday
# Sentiment(polarity=0.025, subjectivity=0.425)
# ----
# Canada closes ports territorial waters to Russian ships The new ban will become part of the sanctions introduced by Canada over Russias all out attack on Ukraine
# Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# ----
# Imagine if Trump vacationed to Mar a Lago right as war broke out between Ukraine amp Russia I guess we will never know because this crap wouldnt happen during his Presidency
# Sentiment(polarity=-0.2571428571428572, subjectivity=0.6678571428571429)
# ----
# My sister was trapped in Ukraine This is a thread about her incredible journey to reach Poland During her escape she experienced racism injuries freezing temps and sleep deprivation Her story is only one of the hundreds of thousands of people trying to get out
# Sentiment(polarity=0.375, subjectivity=0.7)
# ----
# Just had a conversation with The American leadership on anti Russian sanctions and defense assistance to Ukraine was discussed We must stop the aggressor as soon as possible Thank you for your support
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
# ----
# Our teams will be on the ground in Rzeszw Poland Polish border to Ukraine starting February 25 2022 setting up base camp refugee operations with our Polish and Ukrainian partners Thank you Bethany Frankel You are a hero
# Sentiment(polarity=-0.4, subjectivity=0.55)
# ----
# My sister is lucky Shes safe in a hotel where she was finally able to shower and sleep in a bed There are still thousands of people in her shoes trapped on the other side More than half a million refugees have fled Ukraine during the Russian invasion according to the UN
# Sentiment(polarity=0.16770833333333332, subjectivity=0.375)
# ----
# 10K Russians crossing the Ukraine border invasion Why doesn t 2 million crossing the US border invasion Asking for a friend
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# It was learned that the pilot of the Ukrainian Su 27 Flanker fighter jet nicknamed Grey Wolf Colonel Oleksandr Oksanchenko died when his plane was shot down in Kiev on Friday evening Rest in Peace to the fallen He was a hero to his nation Ukraine RussiawarOnUkraine
# Sentiment(polarity=-0.1027777777777778, subjectivity=0.19444444444444448)
# ----
# The high level of fake news from both Ukraine and Russia have turned this conflict into a modern information war That s why the real battle is now done on a psychological level and not fully on the ground This definitely is a dangerous new territory
# Sentiment(polarity=-0.05766233766233765, subjectivity=0.5135064935064936)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# The Russia Ukraine invasion was completely avoidable Had this administration projected strength vs weakness amp taken a few defense steps When will the liberal left stop being naive Bullys like Putin only respect strength We need a leader who projects strength Biden doesnt
# Sentiment(polarity=-0.08, subjectivity=0.5)
# ----
#  How is Czechia helping Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# On the situation in Ukraine We call on both states to make utmost efforts to pursue a dialogue and work on a peaceful settlement There is no other way
# Sentiment(polarity=0.15625, subjectivity=0.4375)
# ----
# Israel is brining aid to ukraine but still slaughtering Palestinians
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# NEW Defence Minister Anita Anand speaking now Canada will provide 1 600 fragmentation vests and nearly 400 000 meal packs to Ukraine at request of that country cdnpoli UkraineRussiaWar
# Sentiment(polarity=0.11818181818181818, subjectivity=0.42727272727272725)
# ----
# Russian invaders helping themselves in a groceries shop in Chernigiv region Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I spoke with the former US Ambassador to Russia about Russia s invasion of Ukraine and the threat of nuclear war Our full conversation will be in Wake Up Call tomorrow
# Sentiment(polarity=0.175, subjectivity=0.275)
# ----
# VICE World News spoke to multiple people who say theyve spent days stranded at the border where Ukrainian border agents have blocked them from crossing yelled and assaulted them
# Sentiment(polarity=-0.05, subjectivity=0.05)
# ----
# I just spoke with President Zelenskyy to discuss our continued support for Ukraine  including security assistance and humanitarian aid  as it defends itself against Russian aggression We will hold Russia accountable and our sanctions are already having a devastating impact
# Sentiment(polarity=-0.5, subjectivity=0.5)
# ----
# Indian and African students trying to flee Ukraine have reported being beaten up mistreated and forced to wait at the border with Poland while Ukrainian nationals are given priority to reach safety
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.1)
# ----
# So actually we are obliged to defend Ukraine from Putin s nuclear blackmail That has been very carefully hidden from us
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667)
# ----
# BP quits Russia in up to 25 billion hit after Ukraine invasion
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Hy Vee has pulled Russian vodka from its shelves due to the current crisis in Ukraine ntv will have more on this story tonight on
# Sentiment(polarity=0.09375, subjectivity=0.31875)
# ----
# This is John Mearsheimer probably the leading geopolitical scholar in the US today in 2015 The West is leading Ukraine down the primrose path and the end result is that Ukraine is going to get wrecked What we re doing is in fact encouraging that outcome
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# ----
# McGovern Response To McCarthy Im not going to be lectured by someone who takes their marching orders from Donald Trump who said Putins invasion of Ukraine is a smart and savvy move I wish the gentleman wouldve condemned that
# Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# 6th day of war StandWithUkraine ukraine StayStrongUkraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Slovenia s consulate in Ukraine destroyed in attack on Kharkiv ministry
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# ...
# Sentiment(polarity=-0.05, subjectivity=0.05)
# ----
# The sanctions will have no material effect Instead of posturing Blinken s job was to prevent a war A simple agreement not to include Ukraine in NATO would have done that Blinken was too busy posing to perceive the realpolitik
# Sentiment(polarity=0.05, subjectivity=0.32857142857142857)
# ----
# Security Council Secretary Oleksiy Danilov Ukraine can launch a pre emptive missile strike on Belarus
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# My heart breaks for everyone in Ukraine however seeing today the hospital for cancer children and pre mature babies on the floor in the basement Cant we help them Its a hospital for cancer victims I hate Putin
# Sentiment(polarity=-0.35000000000000003, subjectivity=0.5)
# ----
# Ukraine Apparently a local transport company helped the Ukrainian Army recover two 9K33M3 Osa AKM systems recovered from the Russian Army
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# He s probably still getting paid by Ukraine I suggested he should go and protect one of the bioweapon labs but apparently he pussied out
# Sentiment(polarity=0.05, subjectivity=0.35)
# ----
# From India the mass support of Congress Party monarchists and paid left wing media for the Banderastani Nazis in Ukraine is making me re evaluate my visceral dislike for Modi and to be glad the Congress Gandhi dynasty has no chance of returning to power again
# Sentiment(polarity=0.25, subjectivity=0.5)
# ----
# Russia is murdering Indian  students This is a tragedy Its also Putins choice He knows there are many Indians in Ukraine Hes bombing civilians anyway
# Sentiment(polarity=0.5, subjectivity=0.5)
# ----
# Oh look who crawled out of his hole
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I am sick of media discussing how weak our President Joe Biden is and making derogatory comments Do you want 45 to be 47 Want to go back to those miserable days Watch your nasty comments because it could happen 45 would wrap Ukraine in a ribbon to give to Putin Biden2024
# Sentiment(polarity=-0.6178571428571429, subjectivity=0.6964285714285714)
# ----
# I wonder if all these people who are proclaiming their support for Ukraine realize they re supporting literal white supremacists
# Sentiment(polarity=0.125, subjectivity=0.125)
# ----
# Ukraine The Ukrainian Territorial Defence Forces took out two more Russian supply trucks again likely to be in Sumy
# Sentiment(polarity=0.16666666666666666, subjectivity=0.5)
# ----
# If youre blaming President Biden or Vice President Harris instead of blaming Vladimir Putin for the attack on Ukraine youre an asshole Period
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# The Lukashenko regime actively aids and abets Russias illegal invasion of Ukraine and will be made to feel the economic consequences for its support for Putin We ve launched a first tranche of sanctions against Belarusian individuals and organisations
# Sentiment(polarity=-0.04583333333333332, subjectivity=0.4083333333333333)
# ----
# We need to flood Twitter with threads like this no one should be allowed to plead ignorance of what Boris and the UK have done to support Ukraine AND for how long
# Sentiment(polarity=-0.05, subjectivity=0.4)
# ----
# Georgians stand with Ukraine  even if their government does not
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Reports are coming in that illegal migrants that were previously stopped at the Polish border when coming in through Belarus are using the chaos and confusion to enter Poland and the EU with Ukraine refugees
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.3333333333333333)
# ----
# Message reading Putin the Hague is waiting for you seen on a road outside the Russian embassy in Vilnius Lithuania
# Sentiment(polarity=0.0, subjectivity=0.025)
# ----
# BREAKING Ukraine s Secretary of the Security Council announces that the elite squad of killers sent by Chechen dictator Ramzan Kadyrov to kill Ukrainian President Zelenskyy on behalf of Putin have been eliminated  IF YOU THINK THIS IS GREAT NEWS
# Sentiment(polarity=0.8, subjectivity=0.75)
# ----
# International Court of Justice in The Hague to hold hearing on Russia s invasion of Ukraine on Monday
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# Raab says EU s entry rules for Ukrainian refugees more generous than UK s because they re closer to Ukraine Will someone show him Ireland on a map
# Sentiment(polarity=0.5, subjectivity=0.5)
# ----
# Tonight is President Biden s State of the Union Putin hates the US with every fiber of his being I greatly fear that he will use that moment 3 00 am Ukraine time to do something brutal and huge That s just his personality
# Sentiment(polarity=0.10833333333333338, subjectivity=0.8833333333333333)
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# Sentiment(polarity=0.04545454545454545, subjectivity=0.18888888888888888)
# ----
# MOSCOW AP Radio station critical of Russian government goes off air after authorities threaten to shut it over Ukraine coverage
# Sentiment(polarity=0.0, subjectivity=0.4)
# ----
# BOOM John Bolton just stunned a Newsmax reporter by saying Donald Trump barely knew where Ukraine was I don t agree with that war monger on pretty much anything but this time I will
# Sentiment(polarity=0.16666666666666666, subjectivity=0.43333333333333335)
# ----
# The people where they are addressed are spoken to as an abstract The government is starting a special operation rather than as individuals Ukraine s We implore you fellow Russians to stop attacking our women and children
# Sentiment(polarity=0.17857142857142858, subjectivity=0.3357142857142857)
# ----
# You mean the Donbas that is part of Ukraine That Russia took by force and then Ukraine tried to take back from the invading russian army Or is there some other Donbas that we don t know about
# Sentiment(polarity=-0.109375, subjectivity=0.265625)
# ----
# Ukraine vs Russia ROTHSCHILDS The TRUTH THREAD Heir to the Rothschild family Nathaniel Rothschild today wrote to members of the British government giving his view that Vladimir Putin is the most dangerous man since the defeat of Hitler PT 1
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.4666666666666666)
# ----
# Another video showing Africans being forcibly removed from the train they were boarding to leave Ukraine
# Sentiment(polarity=0.5, subjectivity=1.0)
# ----
# Why arent all the Republican freedom fighters with stockpiles of AK 47s headed to Ukraine right now to fight
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# ----
# STOP the war now Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# The case against Vladimir Putin With his invasion of Ukraine the Russian president has made himself more vulnerable to prosecution for war crimes
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
# ----
# Wow The Russian Federation has been served by the International Court of Justice The Hague is Calling Out Genocide On Behalf of Ukraine
# Sentiment(polarity=0.03333333333333333, subjectivity=0.3333333333333333)
# ----
# The first day of March brought punishing Russian strikes against Kharkiv warnings of impending strikes against Kyiv and a flow of refugees that brought the overall number to more than 650 000 This was March 1 2022 in photos from the war in Ukraine
# Sentiment(polarity=0.1875, subjectivity=0.20833333333333331)
# ----
# This is how Ukrainian women are preparing to meet Russians Zhytomir Ukraine EMPR RussiaUkraineWar UkraineWillResist StandWithUkraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# I remember the kindness gratitude grace amp strength my dad embodied as he faced death from cancer That s the first time I saw the real measure of a man Now I again see the real measure of a man in Ukraine s Zelenskyy who has shown amazing character in the face of evil amp war
# Sentiment(polarity=0.05, subjectivity=0.5666666666666667)
# ----
# OH MY GOD Q Whats going on in Ukraine  Kamala Ukraine is a country in Europe It exists next to another country called Russia Russia is a bigger country Russia decided to invade a smaller country called Ukraine so basically thats wrong
# Sentiment(polarity=-0.125, subjectivity=0.475)
# ----
# Bloody hell Looking at a message from the Ukraine Library Association concerning the cancellation of their forthcoming conference it basically says We will reschedule just as soon as we have finished vanquishing our invaders Ukrainian Librarians I salute you
# Sentiment(polarity=-0.8, subjectivity=0.9)
# ----
# A refugee camp of 30 tents has been built in Moldova to help Ukrainian refugees People have lined up for hours and some burst into tears after crossing the border We dont know where were going one said And we dont know when were coming back
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# A piece of shrapnel stuck in the Ukrainian passport The document has allegedly saved the life of its 16 year old holder March 1 2022 Mariupol Ukraine
# Sentiment(polarity=0.0, subjectivity=0.15000000000000002)
# ----
# Due to the war in Ukraine the dates in St Petersburg and Moscow are cancelled I bring my support to the Ukrainian people fans and artists who are under the bombs at the moment In the hope that this war will come to an end and that we can all meet again Take care everyone
# Sentiment(polarity=-0.125, subjectivity=0.375)
# ----
# At least 11 people were killed in rocket strikes in residential areas of Kharkiv as both sides readied for a major battle over Ukraine s second largest city
# Sentiment(polarity=-0.109375, subjectivity=0.225)
# ----
# Im not a praying man but if I were I would be on my hands and knees thanking the Almighty that during the worst crisis in Europe since 1945 the United States is led by Joe Biden not Donald Trump
# Sentiment(polarity=-1.0, subjectivity=1.0)
# ----
# Tonight congressional Republicans have a choice support and show unity against Russias war on Ukraine or take cheap shots from the gallery and weaken America I hope they look to the unity among all parties in Ukraine as a model for rallying against evil SOTU
# Sentiment(polarity=-0.3, subjectivity=0.85)
# ----
# Our world doesn t need wars Our world needs more intelligence respect and love StopTheWar Our hearts with Ukraine   StopWar Putin Peace Tbt NoWars
# Sentiment(polarity=0.5, subjectivity=0.55)
# ----
# So basically not bright enough to fully understand the situation here or in Ukraine
# Sentiment(polarity=-0.17500000000000002, subjectivity=0.6499999999999999)
# ----
# 4 4 Ukraine commenting
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# God Bless Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# NEW Ukraines propaganda war on Russia is being led by two former ad tech entrepreneurs A few weeks back they were working on making Ukraine more tech friendly Now theyre leading a cyber army in the info war on Russia
# Sentiment(polarity=0.10162337662337662, subjectivity=0.23636363636363636)
# ----
# Ukraine Holocaust memorial attacked by Russians to anybody still inclined to believe Russias attack is justified to denazify a peaceful and diverse country
# Sentiment(polarity=0.325, subjectivity=0.7)
# ----
# Apple in a statement said that it is joining those around the world who are calling for peace The company has also stopped all exports into its sales channel in the Russia and has disabled traffic and live incidents in Apple Maps in Ukraine as a safety measure
# Sentiment(polarity=-0.03181818181818183, subjectivity=0.4)
# ----
# Proud to stand alongside my Democratic amp Republican colleagues to say with a unified voice We stand with Ukraine
# Sentiment(polarity=0.8, subjectivity=1.0)
# ----
# This is the Ghost of Kyiv During the Russian war against Ukraine he successfully destroyed 21 enemy aircraft We are proud of our hero
# Sentiment(polarity=0.5166666666666667, subjectivity=0.65)
# ----
# Last week Rachel Maddow did a 50 000 foot overview of why tyrants oppress their own citizens with economic and psychic misery and why this means that Putin cannot tolerate a successful democracy within shouting distance
# Sentiment(polarity=0.3875, subjectivity=0.5541666666666667)
# ----
# The French RN under Marine Le Pen is currently shredding 1 2 million copies of its eight page campaign flyer because it contains this photo Of course it would be a total shame if this photo were to spread like wildfire on the Internet Ukraine Anonymous
# Sentiment(polarity=0.0, subjectivity=0.3833333333333333)
# ----
# Someone also tweeted it saying it s from Donbas but why would Russians bomb the literal safest place for them in Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# The GOP line today is that Biden didn t do enough to arm Ukraine They re saying this with straight faces two years after all of them save Romney stood by Trump when he was caught in the act of trying to disarm Ukraine This is why I say shamelessness is their superpower
# Sentiment(polarity=0.1, subjectivity=0.45)
# ----
# Never forget how Trump stood next to Putin and said he believed HIM and not our intelligence community Never forget how Trump and his cronies threatened the Ukraine ambassador and caused her to flee in the middle of the night Never forget how Trump tried to extort Ukraine
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# When life is bigger than a loss  Lovely moment in Lyon where Romania s bogdan offers an extended embrace to Yastremska after the Ukrainian saved two match points to prevail in 3 05 The power of sport to unite is real  The Latest
# Sentiment(polarity=0.26, subjectivity=0.49000000000000005)
# ----
# Tonight President Biden gives his first SOTU address while he is fighting Republicans in Congress amp Russia in Ukraine Lets show our support for him by making IStandWithBiden trend today Use a graphic from in a tweet Please comment IStandWithBiden amp
# Sentiment(polarity=0.125, subjectivity=0.3666666666666667)
# ----
# Biden 15 years ago Apart of a gang of democrats threatening others with pre emptive nukes for the purpose of illegal invasions And won t get militarily involved in a no fly zone over Ukraine Biden won t defend Europe from a Russian occupation of
# Sentiment(polarity=-0.25, subjectivity=0.375)
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# Sentiment(polarity=-0.07291666666666667, subjectivity=0.16666666666666666)
# ----
# Putin lost the disinformation war over Ukraine but the man who laid waste to cities in Syria and Chechnya has a massive convoy heading to Kyiv He doesnt want to just win  he wants to be remembered joins me via
# Sentiment(polarity=0.2, subjectivity=0.375)
# ----
# the people who believed jussie smollett are lecturing me on ukraine lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# ----
# Russian Defense Minister Sergei Shoigu says Russian troops will not occupy Ukraines territory and will take every measure to ensure the safety of civilians
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# WAR IN UKRAINE
# Sentiment(polarity=0.0, subjectivity=0.0)
# ----
# American fossil fuel companies helped fuel Putins criminal war against Ukraine Our global addiction to oil keeps us locked into dangerous cycles of conflict but we can choose a cleaner path to peace The SPIGOT Act will stop the importation of all Russian oil into the U S
# Sentiment(polarity=-0.2, subjectivity=0.29000000000000004)
# ----
# I got off the phone with my friend in Kyiv The first time I ve spoken to her since the invasion began Most of the conversation that lasted only ten minutes was her crying telling me how tired she is She was born in Russia defected to Ukraine because she wanted 1 4
# Sentiment(polarity=0.025000000000000005, subjectivity=0.5222222222222221)
# ----

# %%
#find sentiment vader
analyser = SentimentIntensityAnalyzer()

# %%
help(analyser.polarity_scores)
# Out:
# Help on method polarity_scores in module vaderSentiment.vaderSentiment:
#
# polarity_scores(text) method of vaderSentiment.vaderSentiment.SentimentIntensityAnalyzer instance
#     Return a float for sentiment strength based on the input text.
#     Positive values are positive valence, negative value are negative
#     valence.

# %%
snt = analyser.polarity_scores('This is an examle of a happy tweet')
print(snt)
# Out:
# {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.5719}

# %%
for elem in stripped_tweet_text:
    print (elem)
    print (analyser.polarity_scores(elem))
    print ("----")
# Out:
# Ukrainian player of Manchester City football club Oleksandr Zinchenko enters the field with a Ukrainian flag Ukraine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Bunker broadcast with  CliveMyrieBBC and big thanks to  DeeMcIlveen Robbie Wright  OpsBbc James White amp Ian Jonas  katepeters Kyiv Ukraine
# {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.4404}
# ----
# Ukraine Women amp children are especially vulnerable to the devastating consequences of the ongoing conflict is scaling up efforts to protect children in the country and warning that many young people are profoundly traumatized by the violence
# {'neg': 0.356, 'neu': 0.593, 'pos': 0.051, 'compound': -0.9371}
# ----
# This is a dangerous time in history since the Cuban Missile Crisis Our president won t withhold aid to Ukraine in exchange for dirt on a political opponent Our leaders must be sane competent people VoteBlueNotQ wtpBLUE
# {'neg': 0.202, 'neu': 0.672, 'pos': 0.126, 'compound': -0.5574}
# ----
# Front line reporters in Ukraine are risking their lives to tell us what they can learn As for the rest I m surprised there hasn t been more reporting on Gen Gerasimov the military mover behind Putin He specializes in multidimensional war including kinetic finance and cyber
# {'neg': 0.119, 'neu': 0.845, 'pos': 0.036, 'compound': -0.6486}
# ----
# Russia did not invade under Trump Trump armed Ukraine Presidential debate final and most important didnt cover foreign policy as the world was approaching total peace Trump was the peacemaker America was strong These are only the facts
# {'neg': 0.0, 'neu': 0.736, 'pos': 0.264, 'compound': 0.9039}
# ----
# Ive never been so proud of my country and the president Ive voted for ukraine
# {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.6113}
# ----
# Three NATO Cuntries Bulgaria Poland Slovakia to Transfer 70 Combat Airplanes to Ukraine  TASS
# {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.34}
# ----
# Tonight congressional Republicans have a choice support and show unity against Russias war on Ukraine or take cheap shots from the gallery and weaken America I hope they look to the unity among all parties in Ukraine as a model for rallying against evil SOTU
# {'neg': 0.19, 'neu': 0.668, 'pos': 0.142, 'compound': -0.5859}
# ----
# Howard needs to parachute into Ukraine with an AR 15 and fight the enemy himself
# {'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'compound': -0.7269}
# ----
# Quick thread I want you all to meet Vladimir Bondarenko Hes a blogger from Kiev who really hates the Ukrainian government He also doesnt exist according to Facebook Hes an invention of a Russian troll farm targeting Ukraine His face was made by AI
# {'neg': 0.069, 'neu': 0.903, 'pos': 0.028, 'compound': -0.4391}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Update Canada is stepping up to provide more humanitarian support in Ukraine and neighbouring countries This support will help experienced partners provide emergency health services shelter sanitation food and water and more More details here
# {'neg': 0.061, 'neu': 0.731, 'pos': 0.208, 'compound': 0.7354}
# ----
# Solidarity with the people of Ukraine  IStandWithUkriane   Trafalgar Square London
# {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.296}
# ----
# At 12000 around 60 of Indians in Ukraine have left the country Of the 40 20 are with western border of Ukraine while 20 in conflict zone
# {'neg': 0.081, 'neu': 0.919, 'pos': 0.0, 'compound': -0.3182}
# ----
# Japan US EU to aid refugees after Russia s invasion of Ukraine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# I wish the world would hear this Ukraines chief rabbi Could I have thought that I would be under bombardment of the country where I was born where I have so many friends Who are silent Ppl from all over the world called me Except from Russia
# {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.7251}
# ----
# There you have it Like all wars started by amp funded by the Rothschilds Putin is removing the deep state cabal WEF UN ClintonFoundation 5Eyes Biden Mi5 MOSSAD CIA black hat operators OUT of Ukraine RussianArmy are NOT attacking civilians RussianUkrainianWar
# {'neg': 0.077, 'neu': 0.816, 'pos': 0.107, 'compound': 0.0976}
# ----
# A follower said when she heard the piano she burst out in tears I was touched also This is a man possibly about to die playing his heart amp the heart of Ukraine to the world Please Retweet Russia Putin Russianinvasion UkrainianArmy PutinWarCriminal
# {'neg': 0.105, 'neu': 0.669, 'pos': 0.226, 'compound': 0.7717}
# ----
# Wow The Russian Federation has been served by the International Court of Justice The Hague is Calling Out Genocide On Behalf of Ukraine
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.802}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Did soldiers punch holes in ALL of the trucks armor gas tanks
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
#  Natasha Perakov 29 years old the first Ukrainian fighter pilot died in combat during the Russian invasion of Ukraine Russia Ucrania Ukraine Kyiv Kiev SlavaUkraini
# {'neg': 0.203, 'neu': 0.743, 'pos': 0.054, 'compound': -0.6597}
# ----
# Answer to Is there anything that makes you smile about this horrible war between Russia and Ukraine by Jacob Dave Harrelson
# {'neg': 0.265, 'neu': 0.645, 'pos': 0.09, 'compound': -0.7096}
# ----
# Ukraine came to help us in 91
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# ----
# Ukraines Propaganda Offensive Led By Ad Tech Entrepreneurs Appears To Be Winning
# {'neg': 0.287, 'neu': 0.517, 'pos': 0.195, 'compound': -0.1531}
# ----
# Please do this Go to Google maps go to Moscow or St Petersbourgh pick a restaurant and give a review telling the people in Russia what s happening in Ukraine
# {'neg': 0.0, 'neu': 0.927, 'pos': 0.073, 'compound': 0.3182}
# ----
# News Analysis After miscalculating Ukraines resolve to fight Russian forces are turning to an old pattern of firing on cities and mounting sieges
# {'neg': 0.181, 'neu': 0.725, 'pos': 0.094, 'compound': -0.34}
# ----
# Global charities operating in the UK and Ukraine are appealing for funds to offer aid in the humanitarian crisis bitcoin bc1q8skvh9xsjgntvs0mv3g3pxd8k8xl7spdm82wcf
# {'neg': 0.156, 'neu': 0.722, 'pos': 0.122, 'compound': -0.2263}
# ----
# OH MY GOD Q Whats going on in Ukraine  Kamala Ukraine is a country in Europe It exists next to another country called Russia Russia is a bigger country Russia decided to invade a smaller country called Ukraine so basically thats wrong
# {'neg': 0.073, 'neu': 0.866, 'pos': 0.061, 'compound': -0.1358}
# ----
# Ukrainians fleeing war are receiving a hearty welcome in Poland Hungary and other neighboring counties The different treatment is stark compared to that of Middle Eastern and African migrants and refugees particularly Syrians who came in 2015
# {'neg': 0.093, 'neu': 0.835, 'pos': 0.072, 'compound': -0.2263}
# ----
# BREAKING NEWS U S officials announce that the Russian offensive on Kyiv Ukraines capital is completely stalled  and many Russian battle units have surrendered without a fight   IF YOU THINK THAT THIS IS GREAT NEWS
# {'neg': 0.172, 'neu': 0.671, 'pos': 0.157, 'compound': 0.0834}
# ----
# STOP RUSSIAN AGGRESSION AGAINST UKRAINE CLOSE THE SKY OVER UKRAINE EXCLUDE RUSSIA FROM THE SECURITY COUNCIL StopPutin StopRussiacn
# {'neg': 0.332, 'neu': 0.546, 'pos': 0.122, 'compound': -0.656}
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.5106}
# ----
#  For the past several months the have STOOD IN SOLIDARITY with VladimirPutin as he inched CLOSER to WAR declared Ukraine strategically irrelevant to the US
# {'neg': 0.152, 'neu': 0.752, 'pos': 0.096, 'compound': -0.4019}
# ----
# At least 11 people were killed in rocket strikes in residential areas of Kharkiv as both sides readied for a major battle over Ukraine s second largest city
# {'neg': 0.284, 'neu': 0.716, 'pos': 0.0, 'compound': -0.8718}
# ----
# Hello world How are your kids today Where do they sleep Where do they play Are Russian shells dropping on them Well in Ukraine this is life for the little ones And as I write this the Russian shells are still falling
# {'neg': 0.035, 'neu': 0.865, 'pos': 0.1, 'compound': 0.4404}
# ----
# Jakobowski Traczyk worry that China might conclude from the US decision not to send troops to Ukraine  which is neither a Nato member nor an ally  that it would not defend Taiwan it was an intellectually lazy comparison
# {'neg': 0.126, 'neu': 0.818, 'pos': 0.056, 'compound': -0.4588}
# ----
# Forbes More Russian Billionaires Speak Out Against Putin s War On Ukraine via
# {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'compound': -0.5994}
# ----
# Biden sent Kamala to help defend Ukraines borders but not our own Biden buys Russian crude oil while crushing American energy independence Bidens America Last policies are hurting the very people he is supposed to serve We wont forget this come Election Day
# {'neg': 0.214, 'neu': 0.668, 'pos': 0.117, 'compound': -0.8101}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Jarosaw Perzyski the mayor of a Polish town drove 7 hours to the Ukrainian border where he has handed out stuffed toys to kids whose families are fleeing the Russian invasion From our children to the Ukrainian children  he said handing out gifts
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Sasha chose to stay in Ukraine to take care of her animal rescues Last night a Russian rocket hit her home Her son found her body this morning Another innocent life ended by war RIP Sasha of Ukraine Fkn heartbreaking
# {'neg': 0.139, 'neu': 0.703, 'pos': 0.159, 'compound': 0.0}
# ----
# Airstrikes on Kyiv hit a Holocaust memorial Ukrainian official says
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Ukraine conflict UK sanctions Belarus for role in Russian invasion
# {'neg': 0.204, 'neu': 0.796, 'pos': 0.0, 'compound': -0.3182}
# ----
# Miss B Russia vs Ukraine
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.1531}
# ----
# The illegal and unprovoked invasion of Ukraine is continuing The map below is the latest Defence Intelligence update on the situation in Ukraine 01 March 2022 Find out more about the the UK Government s response  StandWithUkraine
# {'neg': 0.086, 'neu': 0.808, 'pos': 0.107, 'compound': -0.0258}
# ----
# KSA and UAE two US security dependents have influence over energy markets that make their views on Russia and Ukraine more consequential than any US org to the left of the Democratic party But criticizing them online is less consequential yeah well there you go
# {'neg': 0.063, 'neu': 0.75, 'pos': 0.187, 'compound': 0.5403}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Between Russia and Ukraine Priyanka Chaturvedi is fighting with Poland
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.3612}
# ----
# There is a war in Ukraine my home country I am in Poland But my parents friends are still there fighting for our country and their lives All the proceeds will go to support the Ukrainian Army Link is below stopputin stopwar
# {'neg': 0.111, 'neu': 0.739, 'pos': 0.15, 'compound': 0.4588}
# ----
# Be Prepared for Cyber Attack America  MSNBC  Newsweek  CNN  RuhleOnMSNBC Business big and Small are Cyber Target Most Fortune 500 Companies pay more money in CEO Bonus then they spend on Cyber Defense  DHSgov
# {'neg': 0.111, 'neu': 0.718, 'pos': 0.171, 'compound': 0.34}
# ----
# All 4 MEPs voted against it As did only MEP When it comes to choosing between money and Ukraine money won Putin will be pleased
# {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.765}
# ----
# Unarmed citizens trying to block the advance of Russian troops in the Nikolaev region Ukraine Russia RussianUkrainianWar RussiaInvadesUkraine
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.4404}
# ----
# BREAKING REPO Ukrainian Parliament Member Tells Fox News We Not only Fight For Ukraine  We Fight For this NEW WORLD ORDER
# {'neg': 0.109, 'neu': 0.799, 'pos': 0.092, 'compound': -0.1068}
# ----
# OPEC signals it will to stick to plan despite Ukraine invasion
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# {'neg': 0.139, 'neu': 0.796, 'pos': 0.064, 'compound': -0.5813}
# ----
# Update Canada is stepping up to provide more humanitarian support in Ukraine and neighbouring countries This support will help experienced partners provide emergency health services shelter sanitation food and water and more More details here
# {'neg': 0.061, 'neu': 0.731, 'pos': 0.208, 'compound': 0.7354}
# ----
# BREAKING An elite Chechen fighting unit that was sent into Ukraine to kill President Zelensky has been ELIMINATED It was sent by the leader of Russias Chechnya region who is a close ally of Putin
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.802}
# ----
# Hello baby lovers Any chance of blue and yellow pampers Ukraine colours coming to the world Hell I ll purchase some British ones if you can sell me some Union Jacks
# {'neg': 0.121, 'neu': 0.737, 'pos': 0.142, 'compound': -0.0516}
# ----
# We gotta stop looking to do things that aren t going to happen There won t be a no fly zone There won t be NATO troops in Ukraine We need to find what we can do that has maximum effect in the realm of the possible
# {'neg': 0.08, 'neu': 0.785, 'pos': 0.135, 'compound': 0.6124}
# ----
# Khamenei In my view Ukraine is a victim of the crises concocted by the United States There are two lessons to be learnt here States which depend on the support of the U S and Western powers need to know they cannot trust such countries
# {'neg': 0.094, 'neu': 0.799, 'pos': 0.107, 'compound': 0.1774}
# ----
# For those who are paying attention to Ukraine but know little about its recent history or people please see the documentary Winter On Fire
# {'neg': 0.111, 'neu': 0.784, 'pos': 0.105, 'compound': -0.0387}
# ----
#  Trump froze military assistance to Ukraine they said nothing Withheld a White House meeting with Zelenskyy So we are not gonna be lectured by them   Rep Jim McGovern D MA goes off on House Minority Leader McCarthy blaming Russias invasion of Ukraine on Biden
# {'neg': 0.069, 'neu': 0.931, 'pos': 0.0, 'compound': -0.4939}
# ----
# contextualizes Russia s invasion of Ukraine and attempts to provide nuance Putin Zelenskyy Biden
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# EOS Data Analytics issues urgent plea for imagery of Ukraine
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}
# ----
# on Russias human right abuses in Ukraine Violence has driven over half a million Ukrainians from the country in just a few days including children the elderly and people with disabilities who are making harrowing journeys through conflict zones
# {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.875}
# ----
# Janus Henderson on Russia Ukraine via EM lens India is experiencing a boom in business models across all digital verticals funded from domestic multinational and public private equity investors  this will not be Russias future ausbiz
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Canada closes ports territorial waters to Russian ships The new ban will become part of the sanctions introduced by Canada over Russias all out attack on Ukraine
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.7717}
# ----
# Sad news from Ukraine confirming the death of Ihir Usyk pictured here wearing his Rangers Jersey Ihir a Ukrainian citizen died defending his country And when all my life has ended amp death has made it s mark Will you scatter all my ashes On the slopes of Ibrox Park
# {'neg': 0.24, 'neu': 0.76, 'pos': 0.0, 'compound': -0.9382}
# ----
# Ukraine Grateful for William and Kate Support After Meghan and Harry Backlash England William amp Kate If You Wan Stay On Thing You Har Reedy Nation Whitt Plenty To Sy Many Change amp You Not Har Not So Clean You Har One Off The Country You Hon The Sleve
# {'neg': 0.052, 'neu': 0.843, 'pos': 0.105, 'compound': 0.4322}
# ----
# The United States is responsible for what happened in Ukraine the instigator is the U S Lebanon s Hezbollah leader Sayyed Hassan Nasrallah said on Tuesday He also criticized Western countries double standards in handling the Ukraine crisis
# {'neg': 0.144, 'neu': 0.744, 'pos': 0.112, 'compound': -0.3612}
# ----
# This is from anonymous Go to Google maps Type in Russia Type in a city in Russia Click on restaurants Leave a five star review and let them know what is really going on in the Ukraine Advise to get news from outside the country
# {'neg': 0.027, 'neu': 0.973, 'pos': 0.0, 'compound': -0.0516}
# ----
# Practically Ukraine lost entire coast of Azov Sea
# {'neg': 0.247, 'neu': 0.753, 'pos': 0.0, 'compound': -0.3182}
# ----
# I don t believe anything out of Ukraine and Russia Why George Soros and The World Economic Forum are involved
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Wash Post s Hugh Hewitt and Fox News Mike Pompeo lie about Trump s extortion of Ukraine Via Media Matters
# {'neg': 0.0, 'neu': 0.945, 'pos': 0.055, 'compound': 0.0258}
# ----
# You might not like the messenger but the message is important Putin please stop this war Evening Standard
# {'neg': 0.348, 'neu': 0.467, 'pos': 0.185, 'compound': -0.6762}
# ----
# 01 03 2022 StandWithUkraine Ukraine kyiv Not Verified
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Excellent Now we just need the UK US to buy it from the receivers and then fill the damned thing in UkraineUnderAttack Ukraine SlaviaUkraini Russia PiersMorgan
# {'neg': 0.086, 'neu': 0.792, 'pos': 0.122, 'compound': 0.2732}
# ----
# Rather than expressing grief BJP leader amp Union Minister NarayanRane mocking death on Indian student s death BJP should condemn d behaviour of Mr Rane amp should apologize Ukraine indianstudents IndiansInUkraine Shivsena BJP
# {'neg': 0.365, 'neu': 0.604, 'pos': 0.031, 'compound': -0.9423}
# ----
# Stop killing our children Close the sky over Ukraine Exclude russia from the Security Council EN StopPutin StopRussia
# {'neg': 0.341, 'neu': 0.562, 'pos': 0.096, 'compound': -0.7269}
# ----
# Consider how all the War Departments and Ministries over the world were renamed into Defence in late 1940s Everyone s defending nobody s attacking Why does the fighting happen then Well because of criminals bandits terrorists jihadees or as now in Ukraine Nazis
# {'neg': 0.303, 'neu': 0.635, 'pos': 0.062, 'compound': -0.9403}
# ----
# With Corrupt Politicians and a Corrupt Media How Do We Know What Is Best for the US Concerning Ukraine by
# {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.6369}
# ----
# BREAKING McDonalds and KFC will distribute food to Ukranian soldiers and Ukrainians in need  to thank and for STANDING up against Putin s ILLEGAL invasion of Ukraine
# {'neg': 0.136, 'neu': 0.785, 'pos': 0.079, 'compound': -0.4278}
# ----
# Turkish footballer Aykut Demir caused a stir after refusing to wear No To War T shirt in solidarity with Ukraine Thousands of people die every day in the Middle East I feel said too I share the pain of innocent people  Turkey UkraineRussiaWar UkraineRussia
# {'neg': 0.208, 'neu': 0.62, 'pos': 0.171, 'compound': -0.486}
# ----
# I See A lot Of People In This Country Are Rightfully Rallying Behind Ukraine In Its Fights Against Russia Imagine If This Country Rallied Behind Racism Sexism amp Voters SuppressionThe Same Way
# {'neg': 0.185, 'neu': 0.815, 'pos': 0.0, 'compound': -0.7783}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Finnish demonstrators singing today at Russian Embassy in Helsinki a patriotic Finlandia Hymn that was written during a russification period of Finland by Jean Sibelius at the beginning of the 20th century Finland is changed in lyrics to Ukraine Leaded by the  YLChoir
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Russia s censor Roskomnadzor threatens to block Wikipedia for an article on The Russian invasion of Ukraine 2022
# {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.8176}
# ----
# Very heavy Russian MLRS shelling with cluster munitions on Ukraine s Kharkiv City tonight Whenever the Russians and Assad failed to capture a city in Syria they used cluster munitions to punish the besieged people and force them to surrender
# {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compound': -0.7717}
# ----
# 15 things the mainstream media will not show you about whats happening in Ukraine right now
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Belarusians are preventing Russian troops and vehicles from moving inside Belarus Bypol reported Belarusians started to disrupt the operation of railways that carry Russian tanks and cars to the Belarus Ukraine The people of Belarus stand with our neighbors
# {'neg': 0.028, 'neu': 0.972, 'pos': 0.0, 'compound': -0.0258}
# ----
# Nobody want to unfollow you I born in Snina Slovakia the nearest border is Uba like 30km from Ukraine border I understand your feelings
# {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.4215}
# ----
# Stop killing our children Close the sky over Ukraine Exclude russia from the Security Council EN StopPutin StopRussia
# {'neg': 0.341, 'neu': 0.562, 'pos': 0.096, 'compound': -0.7269}
# ----
# NEW Russia has deployed launching systems capable of sending deadly thermobaric rockets at Ukrainian targets a senior U S defense official said today Russia is likely to employ the weapons to terrorize the Ukrainian army and resistance experts said
# {'neg': 0.156, 'neu': 0.756, 'pos': 0.089, 'compound': -0.6249}
# ----
# This is Amazing 80k volunteer soldiers from around the world to join  Forces Poland Ukraine will be forever indebted for your tremendous help during these hard times
# {'neg': 0.042, 'neu': 0.689, 'pos': 0.269, 'compound': 0.8221}
# ----
# I m more likely to believe NATO CIA AZOV or Ukraine will blow it up themselves In order to blame Russia Than to think Putin would do that But Who knows
# {'neg': 0.054, 'neu': 0.946, 'pos': 0.0, 'compound': -0.1779}
# ----
# Where s Kyle Rittenhouse and his gun Does he want to do something about the Ukraine v Russia war Can he get his mom to bring him over county lines again to go defend against an unruly and dangerous mob Or does his ideals align too much with the person doing the damage idk
# {'neg': 0.218, 'neu': 0.733, 'pos': 0.048, 'compound': -0.8979}
# ----
# RUSSIAN INVASION OF UKRAINE LATEST  At least 10 people killed 20 wounded in Kharkiv attack interior ministry adviser says  Zelenskyy If we defend Kyiv we defend the country  Ukrainian ambassador to the U S says Russia used vacuum bomb
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.8957}
# ----
# Hey Lincolnshire Did you vote to be represented like this Is this your values being portrayed to the World including Ukraine I am guessing not I think you d better have a word with your MP Oh A Sir no less too PutinsToryPuppet
# {'neg': 0.045, 'neu': 0.791, 'pos': 0.164, 'compound': 0.7096}
# ----
# STOP the war now Ukraine
# {'neg': 0.695, 'neu': 0.305, 'pos': 0.0, 'compound': -0.7804}
# ----
# Burn motherfucker burn Russian Pantsir S1 missile system destroyed in Ukraine
# {'neg': 0.464, 'neu': 0.536, 'pos': 0.0, 'compound': -0.8316}
# ----
# Lithuanians have donated 10 mil EUR via Blue Yellow At the moment these items are bought and being shipped to Ukraine Military outfits for 130k Optical lenses for 80k Helmets for 810k Bulletproof vests for 630k Medical equipment for 190k Satellite phones for 200k
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Raab the son of a man given refuge in this country from the Nazis is on the radio right now repeating the line that most people want to stay in Ukraine No one is suggesting we force them here Just offer refuge to those who are fleeing why is that so hard
# {'neg': 0.074, 'neu': 0.897, 'pos': 0.029, 'compound': -0.3586}
# ----
# Schumer on Ukraine supplemental spending bill We should be bipartisan on this issue Nothing make Putin happier than for us to be divided
# {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'compound': -0.4168}
# ----
# STOP the war now Ukraine
# {'neg': 0.695, 'neu': 0.305, 'pos': 0.0, 'compound': -0.7804}
# ----
# Oh but they re trying to de Nazify Ukraine smh
# {'neg': 0.247, 'neu': 0.753, 'pos': 0.0, 'compound': -0.4497}
# ----
# BREAKING Soldiers from Belarus have now also invaded Ukraine ALL sanctions against Russia should now be extended 100 to cover Russia AND Belarus
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Reporting with on Ukrainian Canadians and those with no family ties heading to Ukraine to fight Russian aggression Many are flying out tonight UkraineRussiaWar
# {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compound': -0.7184}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# If the entire Russian army joined Ukraine  with that insane round rage monster hiding in his city under ground surrounded by his little servants and yes men every one too scared or equally insane to step up He will just press his shiny red button and we are all screwed
# {'neg': 0.276, 'neu': 0.685, 'pos': 0.039, 'compound': -0.9308}
# ----
# STOP the war now Ukraine
# {'neg': 0.695, 'neu': 0.305, 'pos': 0.0, 'compound': -0.7804}
# ----
# I m leaving the safety of my home in Harrow taking aid to Ukraine  and bringing back desperate refugees I m very apprehensive but their need is bigger than mine Wish us luck we ll post on FB and twitter It s going to be grim but I can no longer sit in Harrow and watch X
# {'neg': 0.136, 'neu': 0.729, 'pos': 0.135, 'compound': -0.0129}
# ----
# For those who are paying attention to Ukraine but know little about its recent history or people please see the documentary Winter On Fire
# {'neg': 0.111, 'neu': 0.784, 'pos': 0.105, 'compound': -0.0387}
# ----
# Well be there ukraine Find your local protest here StopTheWar ClimateJustice StandWithUkraine
# {'neg': 0.142, 'neu': 0.709, 'pos': 0.149, 'compound': 0.0258}
# ----
# Naveens fathers statement should spark a debate about the state of medical education in India He laments about caste based quota and expensive private medical education worth crores  all the reasons why he chose to send his son to Ukraine This should not be ignored
# {'neg': 0.051, 'neu': 0.832, 'pos': 0.117, 'compound': 0.3098}
# ----
# Truly inspiring how crises unite us Indians as one large family Successful amp bright young Indian professionals living in Hungary have taken off from work to selflessly volunteer to help amp assist the students who are coming from Ukraine Kudos for their efforts amp kindness
# {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.9657}
# ----
# The UK will take up to 200 000 refugees from Ukraine who have sponsors or family in the UK The government restricts asylum for Syrian Iraqi and other MENA refugees  most wait 6 months for processing  and backed pushbacks of refugees at sea after 28 000 crossed last year
# {'neg': 0.046, 'neu': 0.933, 'pos': 0.022, 'compound': -0.296}
# ----
# The Europeans are willing to stand up to Russia because they know that Washington has their backs Without staunch U S support which they would never get from Trump the unprecedented Western resolve would melt as quickly as the last snow of spring
# {'neg': 0.026, 'neu': 0.86, 'pos': 0.114, 'compound': 0.6249}
# ----
# Thousands of Russians have been arrested for opposing Vladimir Putins war on Ukraine A socialist detained by police during a protest in Saint Petersburg writes about her arrest and the antiwar movements defiance in the face of state repression
# {'neg': 0.336, 'neu': 0.664, 'pos': 0.0, 'compound': -0.9403}
# ----
# Black students in Ukraine are trapped in basement bunkers struggling to get food money or even an escape route out of the country and you folks are helping Terrell Starr go viral lying about Ukraines neo Nazi problem while they sit and wait to be rescued
# {'neg': 0.212, 'neu': 0.672, 'pos': 0.116, 'compound': -0.765}
# ----
# Biden wearing a mask in support of Ukraine aint enough Ukraine needs proper help time to be courageous like Zelenskyy dont be a USCoward
# {'neg': 0.0, 'neu': 0.639, 'pos': 0.361, 'compound': 0.8834}
# ----
# To be clear there appears to be significant public disapproval within Belarus to invading Ukraine Protests social media activity and even sabotage to stop Russian military transports from moving through It may be the beginning of a democratic awakening in Belarus
# {'neg': 0.157, 'neu': 0.752, 'pos': 0.092, 'compound': -0.4767}
# ----
# Pat Robertson Putin is being compelled by God to invade Ukraine and fulfill biblical prophecy Is he the modern day Assyrian
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.6369}
# ----
# Russian forces escalate attacks on Ukraine s civilian areas from
# {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4404}
# ----
# The number of Russian soldiers killed in Ukraine since February 24 now exceeds 5 000 see Russian source below 1 000 a day This is more than in 8 years of war in Syria Syrian mothers can feel revenged Syrian and Turkish friends please share
# {'neg': 0.18, 'neu': 0.664, 'pos': 0.156, 'compound': -0.5267}
# ----
# Be aware of fake war footage from the Ukraine doing the rounds
# {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.7906}
# ----
# weeman Androwski dont care them You cant tell that is what a stupid idea They eyes full with blood right now Humanitarian support is only all we can do Ukraines president should stop expecting more Its not innocent peoples of other countries fight
# {'neg': 0.249, 'neu': 0.7, 'pos': 0.051, 'compound': -0.8565}
# ----
# It only took 4 days for almost complete global condemnation of Putin for invading Ukraine but we re on Day 715 of 15 Days to Slow the Spread and Xi just finished hosting the Olympics in Beijing with near total backing of global corporations and the media
# {'neg': 0.046, 'neu': 0.921, 'pos': 0.033, 'compound': -0.1726}
# ----
# I spent most of the day checking on points of defense in Kyiv My resistance team is helping out organize the supplies and patrol the city The fun part is people did not expect MPs to stay in town they thought we fled No we did not We are here to fight together Ukraine
# {'neg': 0.079, 'neu': 0.806, 'pos': 0.115, 'compound': 0.296}
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# {'neg': 0.139, 'neu': 0.796, 'pos': 0.064, 'compound': -0.5813}
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.5106}
# ----
# See our Chief Investment Officers weekly take on the markets
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# As per CNN a Russian air strike destroyed a Holocaust memorial near Kyiv Putin thats a funny way of denazifying Ukraine you son of bitch you
# {'neg': 0.254, 'neu': 0.659, 'pos': 0.087, 'compound': -0.6808}
# ----
# Fight back and spread awareness by peeing on Putin literally PEETIN NFT collection for Ukraine fundraising You can find more details here Get them on Opensea Discord
# {'neg': 0.175, 'neu': 0.825, 'pos': 0.0, 'compound': -0.6486}
# ----
# 31 10 20 Hunter Bidens Ukraine contact allegedly a fixer for shady oligarchs Down the rabbithole Nederland HunterBiden Corruption
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Amnesty Internationals Crisis Evidence Lab analyzed digital evidence  including photos videos and satellite imagery of indiscriminate attacks in Ukraine They have verified violations of international law which could amount to war crimes
# {'neg': 0.338, 'neu': 0.662, 'pos': 0.0, 'compound': -0.936}
# ----
# So should we send the freedom fighters from the trucker convoys to Ukraine so they can see what fighting for freedom actually looks like
# {'neg': 0.11, 'neu': 0.565, 'pos': 0.324, 'compound': 0.8481}
# ----
# I spent most of the day checking on points of defense in Kyiv My resistance team is helping out organize the supplies and patrol the city The fun part is people did not expect MPs to stay in town they thought we fled No we did not We are here to fight together Ukraine
# {'neg': 0.079, 'neu': 0.806, 'pos': 0.115, 'compound': 0.296}
# ----
# A lot of people are quoting Marco Rubio on Ukraine They should ask him why he voted to give Donald Trump a pass for illegally withholding military aid from Ukraine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Media exploitation of Russia Ukraine is almost as apalling as their coverage of COVID in terms of using unverified material and creating sensationalism and bias No surprise at all
# {'neg': 0.102, 'neu': 0.828, 'pos': 0.07, 'compound': -0.0036}
# ----
# I just spoke with President Zelenskyy to discuss our continued support for Ukraine  including security assistance and humanitarian aid  as it defends itself against Russian aggression We will hold Russia accountable and our sanctions are already having a devastating impact
# {'neg': 0.137, 'neu': 0.756, 'pos': 0.107, 'compound': -0.34}
# ----
# BREAKING Ukraine s Secretary of the Security Council announces that the elite squad of killers sent by Chechen dictator Ramzan Kadyrov to kill Ukrainian President Zelenskyy on behalf of Putin have been eliminated  IF YOU THINK THIS IS GREAT NEWS
# {'neg': 0.172, 'neu': 0.689, 'pos': 0.138, 'compound': -0.4151}
# ----
# I m probably alone in being confused about Belarus stance on Ukraine Reporting is all over the place On balance it seems like Belarus is rope a doping Putin
# {'neg': 0.131, 'neu': 0.793, 'pos': 0.076, 'compound': -0.2023}
# ----
# Why is Apple mum on Ukraine Hey  Apple  tim cook
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Located the tank training facility reportedly attacked by Russia in Kharkiv Ukraine 49 972141 36 166573
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.4588}
# ----
# People in our community want to express solidarity with Ukraine and show that we are against the war This is the least we can do Tune in 29 02 22 at 18 00 UTC 2 for a 24 hour Skullgirls marathon stream Artwork by NoWar
# {'neg': 0.079, 'neu': 0.85, 'pos': 0.071, 'compound': -0.34}
# ----
# Even the Super Heroes tonight pray for peace between Russia and Ukraine for peace in Europe FatTuesdayofPrayer
# {'neg': 0.0, 'neu': 0.421, 'pos': 0.579, 'compound': 0.9477}
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# {'neg': 0.139, 'neu': 0.796, 'pos': 0.064, 'compound': -0.5813}
# ----
# Poll Amrach Research Q Would you welcome Ukraine as a member of the EU Yes 84 No 5 Unsure 11 February 2022 S 1 000
# {'neg': 0.072, 'neu': 0.685, 'pos': 0.243, 'compound': 0.6416}
# ----
# Two leaders two worlds Freedom will prevail
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}
# ----
# Why is no one covering this Pushed back because were Black Africans stranded at Ukraine Poland border via
# {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.296}
# ----
# That viral video of Ukraines President powerfully shutting down a homophobic heckler  now with more context by A rare public exhibit of passion in defending progressive values by a European leader these days
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.6908}
# ----
# Here is every single member of the European parliament who voted against supporting Ukraine A mix of far right and far left populists Save this list vote them out in 2024
# {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.7269}
# ----
# Current scenes from Ukraine devastating
# {'neg': 0.518, 'neu': 0.482, 'pos': 0.0, 'compound': -0.6486}
# ----
# Thread The most racist Ukraine coverage on TV News 1 The BBC Its very emotional for me because I see European people with blue eyes and blonde hair being killed Ukraines Deputy Chief Prosecutor David Sakvarelidze
# {'neg': 0.201, 'neu': 0.755, 'pos': 0.043, 'compound': -0.836}
# ----
# 5 vile things Trump did to Zelensky amp Ukraine that you forgot about The tfg s track record on Ukraine raises questions about what would happen if he were POTUS again questions that to put it mildly are deeply unsettling indeed StandWithUkraine
# {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.6249}
# ----
# Every voice matters We see you and feel your support Urge your governments to provide Ukraine with more defensive weapons ammunition and economic support Cut all political and business ties with Russia Tell us what country you are supporting us from  StandWithUkraine
# {'neg': 0.103, 'neu': 0.685, 'pos': 0.211, 'compound': 0.5446}
# ----
# The U S has dropped at least 337 000 bombs in the past 20 years and has bombed Syria for 5 years Yemen for 7 years Somalia for 15 years Iraq for 16 years Pakistan for 18 years Afghanistan for 21 years But now you care about Ukraine Exactly when the media tells you to
# {'neg': 0.0, 'neu': 0.926, 'pos': 0.074, 'compound': 0.6486}
# ----
# NoWar We stand for Ukraine SlavaUkraini Practical tips in the thread how you can show support with your website NoCode
# {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.4019}
# ----
# Andrew who has family stuck in Moldova having fled Ukraine says he was told by the Home Office to call back next Monday He says they are charging a fee for the application process Surely surely not
# {'neg': 0.048, 'neu': 0.813, 'pos': 0.139, 'compound': 0.5859}
# ----
# Putin has gone berserk and the civilized world should stop all dealings with Russians until this Tyrant is out of power Russian people need to rise and stop this brutality on Russians who have made Ukraine their peaceful home
# {'neg': 0.193, 'neu': 0.739, 'pos': 0.068, 'compound': -0.714}
# ----
# If you support the announcement that Ukraine will offer money and asylum to any Russian soldier who voluntarily surrenders and abandons the war hit the like button and follow so you don t miss important Ukraine news or a chance to RESIST Putin s ILLEGAL invasion
# {'neg': 0.205, 'neu': 0.643, 'pos': 0.152, 'compound': -0.6289}
# ----
# Rep McGovern after McCarthy finishes speaking on House floor I m not going to be lectured by someone who takes their marching orders from Donald Trump who said Putin s invasion of Ukraine was a genius and savvy move
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# BREAKING An elite Chechen fighting unit that was sent into Ukraine to kill President Zelensky has been ELIMINATED It was sent by the leader of Russias Chechnya region who is a close ally of Putin
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.802}
# ----
# If Tucker wants to know why ppl say he roots for Russia it s because in Dec 2019 he said We should probably take the side of Russia And in November 2021 he said Why would we take Ukraine s side Why aren t we on Russia s side
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Lets make science not war Russian scientists amp science journalists have published an open letter condemning the war with Ukraine calling it unfair and senseless currently over 4 000 signatories Russian English
# {'neg': 0.179, 'neu': 0.741, 'pos': 0.08, 'compound': -0.5932}
# ----
# STOP the war now Ukraine
# {'neg': 0.695, 'neu': 0.305, 'pos': 0.0, 'compound': -0.7804}
# ----
# Did Ukraine turn Anakin to the dark side No End of story
# {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.296}
# ----
# BREAKING President Zelensky asks the United Nations to STRIP Russia s vote at the UN Security Council as punishment for invading Ukraine Should they
# {'neg': 0.109, 'neu': 0.714, 'pos': 0.177, 'compound': 0.25}
# ----
# ua director berates Boris Johnson over the UKs failure to impose tougher sanctions against Russians resident in London or push for a no fly zone over Ukraine during press conference in Poland
# {'neg': 0.206, 'neu': 0.749, 'pos': 0.045, 'compound': -0.7184}
# ----
#  Ukraine s minister of culture says Russia s army plans to destroy a 1000 years old Saint Sophia Cathedral They seek to destroy the entire Ukrainian history trying to steal it  Stalin blew up the neighbouring cathedral which was slightly younger UkraineInvasion
# {'neg': 0.207, 'neu': 0.793, 'pos': 0.0, 'compound': -0.8807}
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# {'neg': 0.139, 'neu': 0.796, 'pos': 0.064, 'compound': -0.5813}
# ----
# Videos show the destruction of Freedom Square in Kharkiv after an apparent rocket struck an administrative building earlier on Tuesday
# {'neg': 0.212, 'neu': 0.632, 'pos': 0.156, 'compound': -0.128}
# ----
# Canada closes ports territorial waters to Russian ships The new ban will become part of the sanctions introduced by Canada over Russias all out attack on Ukraine
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.7717}
# ----
# Imagine if Trump vacationed to Mar a Lago right as war broke out between Ukraine amp Russia I guess we will never know because this crap wouldnt happen during his Presidency
# {'neg': 0.257, 'neu': 0.743, 'pos': 0.0, 'compound': -0.8658}
# ----
# My sister was trapped in Ukraine This is a thread about her incredible journey to reach Poland During her escape she experienced racism injuries freezing temps and sleep deprivation Her story is only one of the hundreds of thousands of people trying to get out
# {'neg': 0.218, 'neu': 0.725, 'pos': 0.057, 'compound': -0.8637}
# ----
# Just had a conversation with The American leadership on anti Russian sanctions and defense assistance to Ukraine was discussed We must stop the aggressor as soon as possible Thank you for your support
# {'neg': 0.158, 'neu': 0.675, 'pos': 0.168, 'compound': 0.1027}
# ----
# Our teams will be on the ground in Rzeszw Poland Polish border to Ukraine starting February 25 2022 setting up base camp refugee operations with our Polish and Ukrainian partners Thank you Bethany Frankel You are a hero
# {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.7269}
# ----
# My sister is lucky Shes safe in a hotel where she was finally able to shower and sleep in a bed There are still thousands of people in her shoes trapped on the other side More than half a million refugees have fled Ukraine during the Russian invasion according to the UN
# {'neg': 0.059, 'neu': 0.843, 'pos': 0.098, 'compound': 0.3182}
# ----
# 10K Russians crossing the Ukraine border invasion Why doesn t 2 million crossing the US border invasion Asking for a friend
# {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.4939}
# ----
# It was learned that the pilot of the Ukrainian Su 27 Flanker fighter jet nicknamed Grey Wolf Colonel Oleksandr Oksanchenko died when his plane was shot down in Kiev on Friday evening Rest in Peace to the fallen He was a hero to his nation Ukraine RussiawarOnUkraine
# {'neg': 0.107, 'neu': 0.719, 'pos': 0.174, 'compound': 0.4215}
# ----
# The high level of fake news from both Ukraine and Russia have turned this conflict into a modern information war That s why the real battle is now done on a psychological level and not fully on the ground This definitely is a dangerous new territory
# {'neg': 0.262, 'neu': 0.684, 'pos': 0.053, 'compound': -0.9042}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# The Russia Ukraine invasion was completely avoidable Had this administration projected strength vs weakness amp taken a few defense steps When will the liberal left stop being naive Bullys like Putin only respect strength We need a leader who projects strength Biden doesnt
# {'neg': 0.123, 'neu': 0.588, 'pos': 0.289, 'compound': 0.8625}
# ----
#  How is Czechia helping Ukraine
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296}
# ----
# On the situation in Ukraine We call on both states to make utmost efforts to pursue a dialogue and work on a peaceful settlement There is no other way
# {'neg': 0.068, 'neu': 0.833, 'pos': 0.099, 'compound': 0.25}
# ----
# Israel is brining aid to ukraine but still slaughtering Palestinians
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# NEW Defence Minister Anita Anand speaking now Canada will provide 1 600 fragmentation vests and nearly 400 000 meal packs to Ukraine at request of that country cdnpoli UkraineRussiaWar
# {'neg': 0.0, 'neu': 0.952, 'pos': 0.048, 'compound': 0.1027}
# ----
# Russian invaders helping themselves in a groceries shop in Chernigiv region Ukraine
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.296}
# ----
# I spoke with the former US Ambassador to Russia about Russia s invasion of Ukraine and the threat of nuclear war Our full conversation will be in Wake Up Call tomorrow
# {'neg': 0.201, 'neu': 0.799, 'pos': 0.0, 'compound': -0.8074}
# ----
# VICE World News spoke to multiple people who say theyve spent days stranded at the border where Ukrainian border agents have blocked them from crossing yelled and assaulted them
# {'neg': 0.169, 'neu': 0.831, 'pos': 0.0, 'compound': -0.6705}
# ----
# I just spoke with President Zelenskyy to discuss our continued support for Ukraine  including security assistance and humanitarian aid  as it defends itself against Russian aggression We will hold Russia accountable and our sanctions are already having a devastating impact
# {'neg': 0.137, 'neu': 0.756, 'pos': 0.107, 'compound': -0.34}
# ----
# Indian and African students trying to flee Ukraine have reported being beaten up mistreated and forced to wait at the border with Poland while Ukrainian nationals are given priority to reach safety
# {'neg': 0.154, 'neu': 0.743, 'pos': 0.103, 'compound': -0.4404}
# ----
# ...
# {'neg': 0.31, 'neu': 0.563, 'pos': 0.127, 'compound': -0.8767}
# ----
# Ukraine Apparently a local transport company helped the Ukrainian Army recover two 9K33M3 Osa AKM systems recovered from the Russian Army
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# He s probably still getting paid by Ukraine I suggested he should go and protect one of the bioweapon labs but apparently he pussied out
# {'neg': 0.0, 'neu': 0.93, 'pos': 0.07, 'compound': 0.2023}
# ----
# From India the mass support of Congress Party monarchists and paid left wing media for the Banderastani Nazis in Ukraine is making me re evaluate my visceral dislike for Modi and to be glad the Congress Gandhi dynasty has no chance of returning to power again
# {'neg': 0.081, 'neu': 0.763, 'pos': 0.156, 'compound': 0.6199}
# ----
# Russia is murdering Indian  students This is a tragedy Its also Putins choice He knows there are many Indians in Ukraine Hes bombing civilians anyway
# {'neg': 0.274, 'neu': 0.726, 'pos': 0.0, 'compound': -0.8658}
# ----
# Oh look who crawled out of his hole
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# I am sick of media discussing how weak our President Joe Biden is and making derogatory comments Do you want 45 to be 47 Want to go back to those miserable days Watch your nasty comments because it could happen 45 would wrap Ukraine in a ribbon to give to Putin Biden2024
# {'neg': 0.211, 'neu': 0.747, 'pos': 0.042, 'compound': -0.9081}
# ----
# I wonder if all these people who are proclaiming their support for Ukraine realize they re supporting literal white supremacists
# {'neg': 0.081, 'neu': 0.691, 'pos': 0.228, 'compound': 0.5574}
# ----
# Ukraine The Ukrainian Territorial Defence Forces took out two more Russian supply trucks again likely to be in Sumy
# {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.1027}
# ----
# If youre blaming President Biden or Vice President Harris instead of blaming Vladimir Putin for the attack on Ukraine youre an asshole Period
# {'neg': 0.322, 'neu': 0.678, 'pos': 0.0, 'compound': -0.8591}
# ----
# BREAKING Glencore one of the world s biggest commodities companies says it condemns the actions taken by the Russian government against the people of Ukraine
# {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.5106}
# ----
# The Lukashenko regime actively aids and abets Russias illegal invasion of Ukraine and will be made to feel the economic consequences for its support for Putin We ve launched a first tranche of sanctions against Belarusian individuals and organisations
# {'neg': 0.08, 'neu': 0.776, 'pos': 0.144, 'compound': 0.2263}
# ----
# We need to flood Twitter with threads like this no one should be allowed to plead ignorance of what Boris and the UK have done to support Ukraine AND for how long
# {'neg': 0.131, 'neu': 0.733, 'pos': 0.136, 'compound': 0.0516}
# ----
# Georgians stand with Ukraine  even if their government does not
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Reports are coming in that illegal migrants that were previously stopped at the Polish border when coming in through Belarus are using the chaos and confusion to enter Poland and the EU with Ukraine refugees
# {'neg': 0.269, 'neu': 0.731, 'pos': 0.0, 'compound': -0.886}
# ----
# Message reading Putin the Hague is waiting for you seen on a road outside the Russian embassy in Vilnius Lithuania
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# BREAKING Ukraine s Secretary of the Security Council announces that the elite squad of killers sent by Chechen dictator Ramzan Kadyrov to kill Ukrainian President Zelenskyy on behalf of Putin have been eliminated  IF YOU THINK THIS IS GREAT NEWS
# {'neg': 0.172, 'neu': 0.689, 'pos': 0.138, 'compound': -0.4151}
# ----
# International Court of Justice in The Hague to hold hearing on Russia s invasion of Ukraine on Monday
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.5267}
# ----
# Raab says EU s entry rules for Ukrainian refugees more generous than UK s because they re closer to Ukraine Will someone show him Ireland on a map
# {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.5563}
# ----
# Tonight is President Biden s State of the Union Putin hates the US with every fiber of his being I greatly fear that he will use that moment 3 00 am Ukraine time to do something brutal and huge That s just his personality
# {'neg': 0.199, 'neu': 0.758, 'pos': 0.044, 'compound': -0.8479}
# ----
# International Court of Justice to hold hearings over Russias war in Ukraine Public hearings on genocide charges against Russia will be held on March 7 8 They will be streamed live
# {'neg': 0.16, 'neu': 0.749, 'pos': 0.091, 'compound': -0.3818}
# ----
# MOSCOW AP Radio station critical of Russian government goes off air after authorities threaten to shut it over Ukraine coverage
# {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.5994}
# ----
# BOOM John Bolton just stunned a Newsmax reporter by saying Donald Trump barely knew where Ukraine was I don t agree with that war monger on pretty much anything but this time I will
# {'neg': 0.097, 'neu': 0.8, 'pos': 0.103, 'compound': 0.0516}
# ----
# The people where they are addressed are spoken to as an abstract The government is starting a special operation rather than as individuals Ukraine s We implore you fellow Russians to stop attacking our women and children
# {'neg': 0.124, 'neu': 0.811, 'pos': 0.064, 'compound': -0.3612}
# ----
# You mean the Donbas that is part of Ukraine That Russia took by force and then Ukraine tried to take back from the invading russian army Or is there some other Donbas that we don t know about
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# Ukraine vs Russia ROTHSCHILDS The TRUTH THREAD Heir to the Rothschild family Nathaniel Rothschild today wrote to members of the British government giving his view that Vladimir Putin is the most dangerous man since the defeat of Hitler PT 1
# {'neg': 0.134, 'neu': 0.753, 'pos': 0.114, 'compound': -0.2406}
# ----
# Another video showing Africans being forcibly removed from the train they were boarding to leave Ukraine
# {'neg': 0.074, 'neu': 0.926, 'pos': 0.0, 'compound': -0.0516}
# ----
# Why arent all the Republican freedom fighters with stockpiles of AK 47s headed to Ukraine right now to fight
# {'neg': 0.158, 'neu': 0.667, 'pos': 0.175, 'compound': 0.34}
# ----
# STOP the war now Ukraine
# {'neg': 0.695, 'neu': 0.305, 'pos': 0.0, 'compound': -0.7804}
# ----
# The case against Vladimir Putin With his invasion of Ukraine the Russian president has made himself more vulnerable to prosecution for war crimes
# {'neg': 0.323, 'neu': 0.677, 'pos': 0.0, 'compound': -0.861}
# ----
# Wow The Russian Federation has been served by the International Court of Justice The Hague is Calling Out Genocide On Behalf of Ukraine
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.802}
# ----
# The first day of March brought punishing Russian strikes against Kharkiv warnings of impending strikes against Kyiv and a flow of refugees that brought the overall number to more than 650 000 This was March 1 2022 in photos from the war in Ukraine
# {'neg': 0.272, 'neu': 0.704, 'pos': 0.024, 'compound': -0.9246}
# ----
# This is how Ukrainian women are preparing to meet Russians Zhytomir Ukraine EMPR RussiaUkraineWar UkraineWillResist StandWithUkraine
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# I remember the kindness gratitude grace amp strength my dad embodied as he faced death from cancer That s the first time I saw the real measure of a man Now I again see the real measure of a man in Ukraine s Zelenskyy who has shown amazing character in the face of evil amp war
# {'neg': 0.208, 'neu': 0.59, 'pos': 0.202, 'compound': -0.3612}
# ----
# OH MY GOD Q Whats going on in Ukraine  Kamala Ukraine is a country in Europe It exists next to another country called Russia Russia is a bigger country Russia decided to invade a smaller country called Ukraine so basically thats wrong
# {'neg': 0.073, 'neu': 0.866, 'pos': 0.061, 'compound': -0.1358}
# ----
# Bloody hell Looking at a message from the Ukraine Library Association concerning the cancellation of their forthcoming conference it basically says We will reschedule just as soon as we have finished vanquishing our invaders Ukrainian Librarians I salute you
# {'neg': 0.169, 'neu': 0.831, 'pos': 0.0, 'compound': -0.8176}
# ----
# A refugee camp of 30 tents has been built in Moldova to help Ukrainian refugees People have lined up for hours and some burst into tears after crossing the border We dont know where were going one said And we dont know when were coming back
# {'neg': 0.039, 'neu': 0.905, 'pos': 0.056, 'compound': 0.2023}
# ----
# A piece of shrapnel stuck in the Ukrainian passport The document has allegedly saved the life of its 16 year old holder March 1 2022 Mariupol Ukraine
# {'neg': 0.067, 'neu': 0.839, 'pos': 0.094, 'compound': 0.2023}
# ----
# Due to the war in Ukraine the dates in St Petersburg and Moscow are cancelled I bring my support to the Ukrainian people fans and artists who are under the bombs at the moment In the hope that this war will come to an end and that we can all meet again Take care everyone
# {'neg': 0.145, 'neu': 0.725, 'pos': 0.13, 'compound': -0.25}
# ----
# At least 11 people were killed in rocket strikes in residential areas of Kharkiv as both sides readied for a major battle over Ukraine s second largest city
# {'neg': 0.284, 'neu': 0.716, 'pos': 0.0, 'compound': -0.8718}
# ----
# Im not a praying man but if I were I would be on my hands and knees thanking the Almighty that during the worst crisis in Europe since 1945 the United States is led by Joe Biden not Donald Trump
# {'neg': 0.245, 'neu': 0.685, 'pos': 0.07, 'compound': -0.8794}
# ----
# Tonight congressional Republicans have a choice support and show unity against Russias war on Ukraine or take cheap shots from the gallery and weaken America I hope they look to the unity among all parties in Ukraine as a model for rallying against evil SOTU
# {'neg': 0.19, 'neu': 0.668, 'pos': 0.142, 'compound': -0.5859}
# ----
# Our world doesn t need wars Our world needs more intelligence respect and love StopTheWar Our hearts with Ukraine   StopWar Putin Peace Tbt NoWars
# {'neg': 0.089, 'neu': 0.446, 'pos': 0.465, 'compound': 0.9448}
# ----
# So basically not bright enough to fully understand the situation here or in Ukraine
# {'neg': 0.17, 'neu': 0.83, 'pos': 0.0, 'compound': -0.3959}
# ----
# 4 4 Ukraine commenting
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ----
# God Bless Ukraine
# {'neg': 0.0, 'neu': 0.169, 'pos': 0.831, 'compound': 0.5994}
# ----
# NEW Ukraines propaganda war on Russia is being led by two former ad tech entrepreneurs A few weeks back they were working on making Ukraine more tech friendly Now theyre leading a cyber army in the info war on Russia
# {'neg': 0.199, 'neu': 0.731, 'pos': 0.071, 'compound': -0.7447}
# ----
# Ukraine Holocaust memorial attacked by Russians to anybody still inclined to believe Russias attack is justified to denazify a peaceful and diverse country
# {'neg': 0.197, 'neu': 0.613, 'pos': 0.19, 'compound': -0.0516}
# ----
# Apple in a statement said that it is joining those around the world who are calling for peace The company has also stopped all exports into its sales channel in the Russia and has disabled traffic and live incidents in Apple Maps in Ukraine as a safety measure
# {'neg': 0.036, 'neu': 0.846, 'pos': 0.118, 'compound': 0.6597}
# ----
# Proud to stand alongside my Democratic amp Republican colleagues to say with a unified voice We stand with Ukraine
# {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.6908}
# ----
# This is the Ghost of Kyiv During the Russian war against Ukraine he successfully destroyed 21 enemy aircraft We are proud of our hero
# {'neg': 0.324, 'neu': 0.427, 'pos': 0.249, 'compound': -0.4588}
# ----
# Last week Rachel Maddow did a 50 000 foot overview of why tyrants oppress their own citizens with economic and psychic misery and why this means that Putin cannot tolerate a successful democracy within shouting distance
# {'neg': 0.166, 'neu': 0.834, 'pos': 0.0, 'compound': -0.7765}
# ----
# The French RN under Marine Le Pen is currently shredding 1 2 million copies of its eight page campaign flyer because it contains this photo Of course it would be a total shame if this photo were to spread like wildfire on the Internet Ukraine Anonymous
# {'neg': 0.068, 'neu': 0.882, 'pos': 0.05, 'compound': -0.2247}
# ----
# Someone also tweeted it saying it s from Donbas but why would Russians bomb the literal safest place for them in Ukraine
# {'neg': 0.154, 'neu': 0.718, 'pos': 0.127, 'compound': -0.1901}
# ----
# The GOP line today is that Biden didn t do enough to arm Ukraine They re saying this with straight faces two years after all of them save Romney stood by Trump when he was caught in the act of trying to disarm Ukraine This is why I say shamelessness is their superpower
# {'neg': 0.042, 'neu': 0.87, 'pos': 0.089, 'compound': 0.4019}
# ----
# Never forget how Trump stood next to Putin and said he believed HIM and not our intelligence community Never forget how Trump and his cronies threatened the Ukraine ambassador and caused her to flee in the middle of the night Never forget how Trump tried to extort Ukraine
# {'neg': 0.104, 'neu': 0.803, 'pos': 0.093, 'compound': -0.3728}
# ----
# When life is bigger than a loss  Lovely moment in Lyon where Romania s bogdan offers an extended embrace to Yastremska after the Ukrainian saved two match points to prevail in 3 05 The power of sport to unite is real  The Latest
# {'neg': 0.046, 'neu': 0.777, 'pos': 0.177, 'compound': 0.765}
# ----
# Tonight President Biden gives his first SOTU address while he is fighting Republicans in Congress amp Russia in Ukraine Lets show our support for him by making IStandWithBiden trend today Use a graphic from in a tweet Please comment IStandWithBiden amp
# {'neg': 0.055, 'neu': 0.835, 'pos': 0.11, 'compound': 0.3612}
# ----
# Biden 15 years ago Apart of a gang of democrats threatening others with pre emptive nukes for the purpose of illegal invasions And won t get militarily involved in a no fly zone over Ukraine Biden won t defend Europe from a Russian occupation of
# {'neg': 0.163, 'neu': 0.707, 'pos': 0.131, 'compound': -0.2023}
# ----
# BREAKING NEWS In a major blow to Russia the International Skating Union bans Russian ice skaters from all international events and competitions in order to punish Russia for its illegal invasion of Ukraine  TO THANK THE INTERNATIONAL SKATING UNION FOR STANDING WITH UKRAINE
# {'neg': 0.139, 'neu': 0.796, 'pos': 0.064, 'compound': -0.5813}
# ----
# Putin lost the disinformation war over Ukraine but the man who laid waste to cities in Syria and Chechnya has a massive convoy heading to Kyiv He doesnt want to just win  he wants to be remembered joins me via
# {'neg': 0.185, 'neu': 0.709, 'pos': 0.105, 'compound': -0.2342}
# ----
# the people who believed jussie smollett are lecturing me on ukraine lol
# {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215}
# ----
# Russian Defense Minister Sergei Shoigu says Russian troops will not occupy Ukraines territory and will take every measure to ensure the safety of civilians
# {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7096}
# ----
# WAR IN UKRAINE
# {'neg': 0.661, 'neu': 0.339, 'pos': 0.0, 'compound': -0.5994}
# ----
# American fossil fuel companies helped fuel Putins criminal war against Ukraine Our global addiction to oil keeps us locked into dangerous cycles of conflict but we can choose a cleaner path to peace The SPIGOT Act will stop the importation of all Russian oil into the U S
# {'neg': 0.172, 'neu': 0.71, 'pos': 0.118, 'compound': -0.0387}
# ----
# I got off the phone with my friend in Kyiv The first time I ve spoken to her since the invasion began Most of the conversation that lasted only ten minutes was her crying telling me how tired she is She was born in Russia defected to Ukraine because she wanted 1 4
# {'neg': 0.143, 'neu': 0.805, 'pos': 0.053, 'compound': -0.6705}
# ----

# %% [markdown]
# ### Stemming/Lemming

# %%
# Stemming / Lemming

### loading a spacy language model
# python -m spacy download en_core_web_sm
# https://spacy.io/models/en
nlp = spacy.load('en_core_web_sm') 

def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

# %% [markdown]
# ### Tokenizing and Corpus Creation

# %%
### Run this the first time
nltk.download('stopwords')

# %%
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')

def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
#Create corupus of all words
words_corpus = []
for elem in stripped_tweet_text:
    # remove stop words
    elem = remove_stopwords(elem)
    # lemmatize text
    elem = lemmatize_text(elem)
    words_corpus.append(elem.lower().split())
print(len(words_corpus))

dictionary = corpora.Dictionary(words_corpus)
print(len(dictionary))
# Out:
# 827
# 3426

# %%
dictionary.num_docs, dictionary.num_pos
# Out:
# (827, 14858)

# %% [markdown]
# ### Topic Modeling

# %%
help(dictionary.filter_extremes)
# Out:
# Help on method filter_extremes in module gensim.corpora.dictionary:
#
# filter_extremes(no_below=5, no_above=0.5, keep_n=100000, keep_tokens=None) method of gensim.corpora.dictionary.Dictionary instance
#     Filter out tokens in the dictionary by their frequency.
#
#     Parameters
#     ----------
#     no_below : int, optional
#         Keep tokens which are contained in at least `no_below` documents.
#     no_above : float, optional
#         Keep tokens which are contained in no more than `no_above` documents
#         (fraction of total corpus size, not an absolute number).
#     keep_n : int, optional
#         Keep only the first `keep_n` most frequent tokens.
#     keep_tokens : iterable of str
#         Iterable of tokens that **must** stay in dictionary after filtering.
#
#     Notes
#     -----
#     This removes all tokens in the dictionary that are:
#
#     #. Less frequent than `no_below` documents (absolute number, e.g. `5`) or
#
#     #. More frequent than `no_above` documents (fraction of the total corpus size, e.g. `0.3`).
#     #. After (1) and (2), keep only the first `keep_n` most frequent tokens (or keep all if `keep_n=None`).
#
#     After the pruning, resulting gaps in word ids are shrunk.
#     Due to this gap shrinking, **the same word may have a different word id before and after the call
#     to this function!**
#
#     Examples
#     --------
#     .. sourcecode:: pycon
#
#         >>> from gensim.corpora import Dictionary
#         >>>
#         >>> corpus = [["máma", "mele", "maso"], ["ema", "má", "máma"]]
#         >>> dct = Dictionary(corpus)
#         >>> len(dct)
#         5
#         >>> dct.filter_extremes(no_below=1, no_above=0.5, keep_n=1)
#         >>> len(dct)
#         1

# %%
dictionary = corpora.Dictionary(words_corpus)
dictionary.filter_extremes(no_below=125, no_above=0.2, keep_n=10000)

corpus_bow = [dictionary.doc2bow(text) for text in words_corpus]

# Term Frequency - Inverse Document Frequency

from gensim import corpora, models

# https://radimrehurek.com/gensim/models/ldamodel.html

tfidf = models.TfidfModel(corpus_bow)
corpus_tfidf = tfidf[corpus_bow]

# %%
# Only 2 topics this time for simplicity
num_topics = 2
lda_model_tfidf = models.LdaMulticore(corpus_tfidf, num_topics=num_topics, id2word=dictionary, passes=4, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.924*"russian" + 0.076*"war"
# Topic: 1 Word: 0.850*"war" + 0.150*"russian"

# %% [markdown]
# ### Part of Speech Tagging

# %%
sentence = 'London is the capital and most populous city of England and the United Kingdom'
sentence_nlp = nlp(sentence)

# %%
from spacy import displacy
displacy.render(sentence_nlp, jupyter=True, 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8754bf6f735549b78719715e806199f0-0" class="displacy" width="1590" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">London</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">capital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">populous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">England</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">Kingdom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-0" stroke-width="2px" d="M70,167.0 C70,112.0 150.0,112.0 150.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L64,159.0 76,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-1" stroke-width="2px" d="M290,167.0 C290,112.0 370.0,112.0 370.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,169.0 L284,159.0 296,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-2" stroke-width="2px" d="M180,167.0 C180,57.0 375.0,57.0 375.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M375.0,169.0 L381.0,159.0 369.0,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-3" stroke-width="2px" d="M400,167.0 C400,112.0 480.0,112.0 480.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,169.0 L486.0,159.0 474.0,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-4" stroke-width="2px" d="M620,167.0 C620,112.0 700.0,112.0 700.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,169.0 L614,159.0 626,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-5" stroke-width="2px" d="M730,167.0 C730,112.0 810.0,112.0 810.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,169.0 L724,159.0 736,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-6" stroke-width="2px" d="M400,167.0 C400,2.0 820.0,2.0 820.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8754bf6f735549b78719715e806199f0-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M820.0,169.0 L826.0,159.0 814.0,159.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8754bf6f735549b78719715e806199f0-0-7" stroke-width="2px" d="M840,167.0 C840,

# %%
# print named entities in article
print([(word, word.ent_type_) for word in sentence_nlp if word.ent_type_])

# visualize named entities
displacy.render(sentence_nlp, style='ent', jupyter=True)
# Out:
# [(London, 'GPE'), (England, 'GPE'), (the, 'GPE'), (United, 'GPE'), (Kingdom, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is the capital and most populous city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
